# %%
! pip install -q --upgrade google-generativeai langchain-google-genai chromadb pypdf
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-cloud-datastore 2.19.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 5.28.3 which is incompatible.
# google-cloud-firestore 2.16.1 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 5.28.3 which is incompatible.
# llama-index-embeddings-gemini 0.2.2 requires google-generativeai<0.6.0,>=0.5.2, but you have google-generativeai 0.8.3 which is incompatible.
# llama-index-readers-file 0.2.2 requires pypdf<5.0.0,>=4.0.1, but you have pypdf 5.1.0 which is incompatible.
# tensorboard 2.17.0 requires protobuf!=4.24.0,<5.0.0,>=3.19.6, but you have protobuf 5.28.3 which is incompatible.
# tensorflow 2.17.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 5.28.3 which is incompatible.
# tensorflow-metadata 1.16.1 requires protobuf<4.21,>=3.20.3; python_version < "3.11", but you have protobuf 5.28.3 which is incompatible.

# %%
# Install the Langchain which is a versatile framework designed to streamline the creation of applications driven by generative AI
# !pip install -q langchain
# Install the OpenAI library, which provides access to OpenAI's powerful language models and APIs.
# !pip install -q openai
# Install faiss-cpu (Facebook AI Similarity Search), a library for efficient similarity search and clustering of dense vectors.
# !pip install -q faiss-cpu
# Install tiktoken, which is a Python library for counting the number of tokens in a text string without making API requests. We will use it in the OpenAI's API token usage monitoring.
# !pip install -q tiktoken
# Install PyMuPDF, a Python library for working with PDF documents. We will use to extract text from PDFs.
# !pip install -q PyMuPDF
# Install docx2txt, a library for extracting text from Microsoft Word (.docx) documents. Useful for text extraction and analysis from Word files.
# !pip install -q docx2txt
# !pip install -q langchain-community
# !pip install llama-index 'google-generativeai>=0.3.0' matplotlib
# %pip install llama-index-embeddings-gemini
# !pip3 install sentence_transformers
# !pip install fitz
# Out:
# Requirement already satisfied: llama-index in /usr/local/lib/python3.10/dist-packages (0.11.22)
# Requirement already satisfied: google-generativeai>=0.3.0 in /usr/local/lib/python3.10/dist-packages (0.8.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.8.0)
# Requirement already satisfied: llama-index-agent-openai<0.4.0,>=0.3.4 in /usr/local/lib/python3.10/dist-packages (from llama-index) (0.3.4)
# Requirement already satisfied: llama-index-cli<0.4.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from llama-index) (0.3.1)
# Requirement already satisfied: llama-index-core<0.12.0,>=0.11.22 in /usr/local/lib/python3.10/dist-packages (from llama-index) (0.11.22)
# Requirement already satisfied: llama-index-embeddings-openai<0.3.0,>=0.2.4 in /usr/local/lib/python3.10/dist-packages (from llama-index) (0.2.5)
# Requirement already satisfied: llama-index-indices-managed-llama-cloud>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from llama-index) (0.4.0)
# Requirement already satisfied: llama-index-legacy<0.10.0,>=0.9.48 in /usr/local/lib/python3.10/dist-packages (from llama-index) (0.9.48.post4)
# Requirement already satisfied: llama-index-llms-openai<0.3.0,>=0.2.10 in /usr/local/lib/python3.10/dist-packages (from llama-index) (0.2.16)
# Requirement already satisfied: llama-index-multi-modal-llms-openai<0.3.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from llama-index) (0.2.3)
# Requirement already satisfied: llama-index-program-openai<0.3.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from llama-index) (0.2.0)
# Requirement already satisfied: llama-index-question-gen-openai<0.3.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from llama-index) (0.2.0)
# Requirement already satisfied: llama-index-readers-file<0.3.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from llama-index) (0.2.2)
# Requirement already satisfied: llama-index-readers-llama-parse>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from llama-index) (0.3.0)
# Requirement already satisfied: nltk>3.8.1 in /usr/local/lib/python3.10/dist-packages (from llama-index) (3.9.1)
# Requirement already satisfied: google-ai-generativelanguage==0.6.10 in /usr/local/lib/python3.10/dist-packages (from google-generativeai>=0.3.0) (0.6.10)
# Requirement already satisfied: google-api-core in /usr/local/lib/python3.10/dist-packages (from google-generativeai>=0.3.0) (2.19.2)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.10/dist-packages (from google-generativeai>=0.3.0) (2.137.0)
# Requirement already satisfied: google-auth>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from google-generativeai>=0.3.0) (2.27.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from google-generativeai>=0.3.0) (5.28.3)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.10/dist-packages (from google-generativeai>=0.3.0) (2.9.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from google-generativeai>=0.3.0) (4.66.6)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from google-generativeai>=0.3.0) (4.12.2)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from google-ai-generativelanguage==0.6.10->google-generativeai>=0.3.0) (1.25.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy<2,>=1.21 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core->google-generativeai>=0.3.0) (1.65.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /usr/local/lib/python3.10/dist-packages (from google-api-core->google-generativeai>=0.3.0) (2.32.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=2.15.0->google-generativeai>=0.3.0) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth>=2.15.0->google-generativeai>=0.3.0) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth>=2.15.0->google-generativeai>=0.3.0) (4.9)
# Requirement already satisfied: openai>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-agent-openai<0.4.0,>=0.3.4->llama-index) (1.52.2)
# Requirement already satisfied: PyYAML>=6.0.1 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.22->llama-index) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.22->llama-index) (2.0.35)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.22->llama-index) (3.10.10)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.22->llama-index) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.22->llama-index) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.22->llama-index) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.22->llama-index) (2024.10.0)
# Requirement already satisfied: httpx in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.22->llama-index) (0.27.2)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.22->llama-index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.22->llama-index) (3.4.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.22->llama-index) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.22->llama-index) (0.8.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.22->llama-index) (0.9.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.22->llama-index) (1.16.0)
# Requirement already satisfied: llama-cloud>=0.0.11 in /usr/local/lib/python3.10/dist-packages (from llama-index-indices-managed-llama-cloud>=0.3.0->llama-index) (0.1.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from llama-index-legacy<0.10.0,>=0.9.48->llama-index) (2.2.2)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in /usr/local/lib/python3.10/dist-packages (from llama-index-readers-file<0.3.0,>=0.2.0->llama-index) (4.12.3)
# Collecting pypdf<5.0.0,>=4.0.1 (from llama-index-readers-file<0.3.0,>=0.2.0->llama-index)
#   Using cached pypdf-4.3.1-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in /usr/local/lib/python3.10/dist-packages (from llama-index-readers-file<0.3.0,>=0.2.0->llama-index) (0.0.26)
# Requirement already satisfied: llama-parse>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-readers-llama-parse>=0.3.0->llama-index) (0.5.13)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>3.8.1->llama-index) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>3.8.1->llama-index) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>3.8.1->llama-index) (2024.9.11)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic->google-generativeai>=0.3.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic->google-generativeai>=0.3.0) (2.23.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client->google-generativeai>=0.3.0) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client->google-generativeai>=0.3.0) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client->google-generativeai>=0.3.0) (4.1.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.22->llama-index) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.22->llama-index) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.22->llama-index) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.22->llama-index) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.22->llama-index) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.22->llama-index) (1.17.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.22->llama-index) (4.0.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.3.0,>=0.2.0->llama-index) (2.6)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.10->google-generativeai>=0.3.0) (1.64.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.10->google-generativeai>=0.3.0) (1.48.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.12.0,>=0.11.22->llama-index) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.12.0,>=0.11.22->llama-index) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.12.0,>=0.11.22->llama-index) (1.0.6)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.12.0,>=0.11.22->llama-index) (3.10)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.12.0,>=0.11.22->llama-index) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx->llama-index-core<0.12.0,>=0.11.22->llama-index) (0.14.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from openai>=1.14.0->llama-index-agent-openai<0.4.0,>=0.3.4->llama-index) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from openai>=1.14.0->llama-index-agent-openai<0.4.0,>=0.3.4->llama-index) (0.6.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai>=0.3.0) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai>=0.3.0) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai>=0.3.0) (2.2.3)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.22->llama-index) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect>=0.8.0->llama-index-core<0.12.0,>=0.11.22->llama-index) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json->llama-index-core<0.12.0,>=0.11.22->llama-index) (3.23.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama-index) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama-index) (2024.2)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx->llama-index-core<0.12.0,>=0.11.22->llama-index) (1.2.2)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.22->llama-index) (0.2.0)
# Using cached pypdf-4.3.1-py3-none-any.whl (295 kB)
# Installing collected packages: pypdf
#   Attempting uninstall: pypdf
#     Found existing installation: pypdf 5.1.0
#     Uninstalling pypdf-5.1.0:
#       Successfully uninstalled pypdf-5.1.0
# Successfully installed pypdf-4.3.1
# Requirement already satisfied: llama-index-embeddings-gemini in /usr/local/lib/python3.10/dist-packages (0.2.2)
# Collecting google-generativeai<0.6.0,>=0.5.2 (from llama-index-embeddings-gemini)
#   Using cached google_generativeai-0.5.4-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: llama-index-core<0.12.0,>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-embeddings-gemini) (0.11.22)
# Collecting google-ai-generativelanguage==0.6.4 (from google-generativeai<0.6.0,>=0.5.2->llama-index-embeddings-gemini)
#   Using cached google_ai_generativelanguage-0.6.4-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: google-api-core in /usr/local/lib/python3.10/dist-packages (from google-generativeai<0.6.0,>=0.5.2->llama-index-embeddings-gemini) (2.19.2)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.10/dist-packages (from google-generativeai<0.6.0,>=0.5.2->llama-index-embeddings-gemini) (2.137.0)
# Requirement already satisfied: google-auth>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from google-generativeai<0.6.0,>=0.5.2->llama-index-embeddings-gemini) (2.27.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from google-generativeai<0.6.0,>=0.5.2->llama-index-embeddings-gemini) (5.28.3)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.10/dist-packages (from google-generativeai<0.6.0,>=0.5.2->llama-index-embeddings-gemini) (2.9.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from google-generativeai<0.6.0,>=0.5.2->llama-index-embeddings-gemini) (4.66.6)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from google-generativeai<0.6.0,>=0.5.2->llama-index-embeddings-gemini) (4.12.2)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from google-ai-generativelanguage==0.6.4->google-generativeai<0.6.0,>=0.5.2->llama-index-embeddings-gemini) (1.25.0)
# Collecting protobuf (from google-generativeai<0.6.0,>=0.5.2->llama-index-embeddings-gemini)
#   Using cached protobuf-4.25.5-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Requirement already satisfied: PyYAML>=6.0.1 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-gemini) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-gemini) (2.0.35)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-gemini) (3.10.10)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-gemini) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-gemini) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-gemini) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-gemini) (2024.10.0)
# Requirement already satisfied: httpx in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-gemini) (0.27.2)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-gemini) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-gemini) (3.4.2)
# Requirement already satisfied: nltk>3.8.1 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-gemini) (3.9.1)
# Requirement already satisfied: numpy<2.0.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-gemini) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-gemini) (10.4.0)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-gemini) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-gemini) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-gemini) (0.8.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-gemini) (0.9.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-gemini) (1.16.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-gemini) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-gemini) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-gemini) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-gemini) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-gemini) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-gemini) (1.17.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-gemini) (4.0.3)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core->google-generativeai<0.6.0,>=0.5.2->llama-index-embeddings-gemini) (1.65.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=2.15.0->google-generativeai<0.6.0,>=0.5.2->llama-index-embeddings-gemini) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth>=2.15.0->google-generativeai<0.6.0,>=0.5.2->llama-index-embeddings-gemini) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth>=2.15.0->google-generativeai<0.6.0,>=0.5.2->llama-index-embeddings-gemini) (4.9)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-gemini) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-gemini) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-gemini) (2024.9.11)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic->google-generativeai<0.6.0,>=0.5.2->llama-index-embeddings-gemini) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic->google-generativeai<0.6.0,>=0.5.2->llama-index-embeddings-gemini) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-gemini) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-gemini) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-gemini) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-gemini) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-gemini) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect>=0.8.0->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-gemini) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-gemini) (3.23.1)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client->google-generativeai<0.6.0,>=0.5.2->llama-index-embeddings-gemini) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client->google-generativeai<0.6.0,>=0.5.2->llama-index-embeddings-gemini) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client->google-generativeai<0.6.0,>=0.5.2->llama-index-embeddings-gemini) (4.1.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-gemini) (3.7.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-gemini) (1.0.6)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-gemini) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-gemini) (0.14.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.4->google-generativeai<0.6.0,>=0.5.2->llama-index-embeddings-gemini) (1.64.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.4->google-generativeai<0.6.0,>=0.5.2->llama-index-embeddings-gemini) (1.48.2)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client->google-generativeai<0.6.0,>=0.5.2->llama-index-embeddings-gemini) (3.2.0)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.10/dist-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-gemini) (24.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai<0.6.0,>=0.5.2->llama-index-embeddings-gemini) (0.6.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-gemini) (0.2.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-gemini) (1.2.2)
# Using cached google_generativeai-0.5.4-py3-none-any.whl (150 kB)
# Using cached google_ai_generativelanguage-0.6.4-py3-none-any.whl (679 kB)
# Using cached protobuf-4.25.5-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
# Installing collected packages: protobuf, google-ai-generativelanguage, google-generativeai
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.28.3
#     Uninstalling protobuf-5.28.3:
#       Successfully uninstalled protobuf-5.28.3
#   Attempting uninstall: google-ai-generativelanguage
#     Found existing installation: google-ai-generativelanguage 0.6.10
#     Uninstalling google-ai-generativelanguage-0.6.10:
#       Successfully uninstalled google-ai-generativelanguage-0.6.10
#   Attempting uninstall: google-generativeai
#     Found existing installation: google-generativeai 0.8.3
#     Uninstalling google-generativeai-0.8.3:
#       Successfully uninstalled google-generativeai-0.8.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-google-genai 2.0.4 requires google-generativeai<0.9.0,>=0.8.0, but you have google-generativeai 0.5.4 which is incompatible.
# opentelemetry-proto 1.28.1 requires protobuf<6.0,>=5.0, but you have protobuf 4.25.5 which is incompatible.
# tensorflow-metadata 1.16.1 requires protobuf<4.21,>=3.20.3; python_version < "3.11", but you have protobuf 4.25.5 which is incompatible.
# Successfully installed google-ai-generativelanguage-0.6.4 google-generativeai-0.5.4 protobuf-4.25.5
# Requirement already satisfied: sentence_transformers in /usr/local/lib/python3.10/dist-packages (3.2.1)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (4.44.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (4.66.6)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (2.5.0+cu121)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.5.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (0.24.7)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (10.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence_transformers) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence_transformers) (2024.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence_transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence_transformers) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence_transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence_transformers) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence_transformers) (1.3.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (2024.9.11)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (0.19.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence_transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence_transformers) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence_transformers) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (2024.8.30)
# Requirement already satisfied: fitz in /usr/local/lib/python3.10/dist-packages (0.0.1.dev2)
# Requirement already satisfied: configobj in /usr/local/lib/python3.10/dist-packages (from fitz) (5.0.9)
# Requirement already satisfied: configparser in /usr/local/lib/python3.10/dist-packages (from fitz) (7.1.0)
# Requirement already satisfied: httplib2 in /usr/local/lib/python3.10/dist-packages (from fitz) (0.22.0)
# Requirement already satisfied: nibabel in /usr/local/lib/python3.10/dist-packages (from fitz) (5.3.2)
# Requirement already satisfied: nipype in /usr/local/lib/python3.10/dist-packages (from fitz) (1.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from fitz) (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from fitz) (2.2.2)
# Requirement already satisfied: pyxnat in /usr/local/lib/python3.10/dist-packages (from fitz) (1.6.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from fitz) (1.13.1)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from httplib2->fitz) (3.2.0)
# Requirement already satisfied: importlib-resources>=5.12 in /usr/local/lib/python3.10/dist-packages (from nibabel->fitz) (6.4.5)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.10/dist-packages (from nibabel->fitz) (24.1)
# Requirement already satisfied: typing-extensions>=4.6 in /usr/local/lib/python3.10/dist-packages (from nibabel->fitz) (4.12.2)
# Requirement already satisfied: click>=6.6.0 in /usr/local/lib/python3.10/dist-packages (from nipype->fitz) (8.1.7)
# Requirement already satisfied: networkx>=2.0 in /usr/local/lib/python3.10/dist-packages (from nipype->fitz) (3.4.2)
# Requirement already satisfied: prov>=1.5.2 in /usr/local/lib/python3.10/dist-packages (from nipype->fitz) (2.0.1)
# Requirement already satisfied: pydot>=1.2.3 in /usr/local/lib/python3.10/dist-packages (from nipype->fitz) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.2 in /usr/local/lib/python3.10/dist-packages (from nipype->fitz) (2.8.2)
# Requirement already satisfied: rdflib>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from nipype->fitz) (6.3.2)
# Requirement already satisfied: simplejson>=3.8.0 in /usr/local/lib/python3.10/dist-packages (from nipype->fitz) (3.19.3)
# Requirement already satisfied: traits!=5.0,>=4.6 in /usr/local/lib/python3.10/dist-packages (from nipype->fitz) (6.4.3)
# Requirement already satisfied: filelock>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from nipype->fitz) (3.16.1)
# Requirement already satisfied: etelemetry>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from nipype->fitz) (0.3.1)
# Requirement already satisfied: looseversion!=1.2 in /usr/local/lib/python3.10/dist-packages (from nipype->fitz) (1.3.0)
# Requirement already satisfied: puremagic in /usr/local/lib/python3.10/dist-packages (from nipype->fitz) (1.28)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->fitz) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->fitz) (2024.2)
# Requirement already satisfied: lxml>=4.3 in /usr/local/lib/python3.10/dist-packages (from pyxnat->fitz) (5.3.0)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.10/dist-packages (from pyxnat->fitz) (2.32.3)
# Requirement already satisfied: pathlib>=1.0 in /usr/local/lib/python3.10/dist-packages (from pyxnat->fitz) (1.0.1)
# Requirement already satisfied: ci-info>=0.2 in /usr/local/lib/python3.10/dist-packages (from etelemetry>=0.2.0->nipype->fitz) (0.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.2->nipype->fitz) (1.16.0)
# Requirement already satisfied: isodate<0.7.0,>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from rdflib>=5.0.0->nipype->fitz) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->pyxnat->fitz) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->pyxnat->fitz) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->pyxnat->fitz) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->pyxnat->fitz) (2024.8.30)

# %%
from IPython.display import display
from IPython.display import Markdown
import textwrap


def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# %%
import google.generativeai as genai
from google.colab import userdata

# %%
from google.colab import userdata
# The gemini api key
GOOGLE_API_KEY = userdata.get('GOOGLE_API_KEY')
print(GOOGLE_API_KEY)
# Out:
# AIzaSyAsdJzG-XslY5w7i7aHWijyd3iLa4ElgPg

# %%
genai.configure(api_key=GOOGLE_API_KEY)

# %% [markdown]
# Text generation

# %%
model = genai.GenerativeModel(model_name = "gemini-pro")
model
# Out:
# genai.GenerativeModel(
#     model_name='models/gemini-pro',
#     generation_config={},
#     safety_settings={},
#     tools=None,
#     system_instruction=None,
# )

# %% [markdown]
# Using langChain to Access Gemini API

# %%
# !pip install google-generativeai --upgrade
# Out:
# Requirement already satisfied: google-generativeai in /usr/local/lib/python3.10/dist-packages (0.5.4)
# Collecting google-generativeai
#   Using cached google_generativeai-0.8.3-py3-none-any.whl.metadata (3.9 kB)
# Collecting google-ai-generativelanguage==0.6.10 (from google-generativeai)
#   Using cached google_ai_generativelanguage-0.6.10-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: google-api-core in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (2.19.2)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (2.137.0)
# Requirement already satisfied: google-auth>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (2.27.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (4.25.5)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (2.9.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (4.66.6)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (4.12.2)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from google-ai-generativelanguage==0.6.10->google-generativeai) (1.25.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core->google-generativeai) (1.65.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /usr/local/lib/python3.10/dist-packages (from google-api-core->google-generativeai) (2.32.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=2.15.0->google-generativeai) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth>=2.15.0->google-generativeai) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth>=2.15.0->google-generativeai) (4.9)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client->google-generativeai) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client->google-generativeai) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client->google-generativeai) (4.1.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic->google-generativeai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic->google-generativeai) (2.23.4)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.10->google-generativeai) (1.64.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.10->google-generativeai) (1.48.2)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client->google-generativeai) (3.2.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (2024.8.30)
# Using cached google_generativeai-0.8.3-py3-none-any.whl (160 kB)
# Using cached google_ai_generativelanguage-0.6.10-py3-none-any.whl (760 kB)
# Installing collected packages: google-ai-generativelanguage, google-generativeai
#   Attempting uninstall: google-ai-generativelanguage
#     Found existing installation: google-ai-generativelanguage 0.6.4
#     Uninstalling google-ai-generativelanguage-0.6.4:
#       Successfully uninstalled google-ai-generativelanguage-0.6.4
#   Attempting uninstall: google-generativeai
#     Found existing installation: google-generativeai 0.5.4
#     Uninstalling google-generativeai-0.5.4:
#       Successfully uninstalled google-generativeai-0.5.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llama-index-embeddings-gemini 0.2.2 requires google-generativeai<0.6.0,>=0.5.2, but you have google-generativeai 0.8.3 which is incompatible.
# Successfully installed google-ai-generativelanguage-0.6.10 google-generativeai-0.8.3

# %% [markdown]
# **Processing Documents with RAG**

# %%
# !sudo apt -y -qq install tesseract-ocr libtesseract-dev

# !sudo apt-get -y -qq install poppler-utils libxml2-dev libxslt1-dev antiword unrtf poppler-utils pstotext tesseract-ocr flac ffmpeg lame libmad0 libsox-fmt-mp3 sox libjpeg-dev swig

# !pip install langchain langchain-community
# Out:
# The following additional packages will be installed:
#   libarchive-dev libleptonica-dev tesseract-ocr-eng tesseract-ocr-osd
# The following NEW packages will be installed:
#   libarchive-dev libleptonica-dev libtesseract-dev tesseract-ocr
#   tesseract-ocr-eng tesseract-ocr-osd
# 0 upgraded, 6 newly installed, 0 to remove and 49 not upgraded.
# Need to get 8,560 kB of archives.
# After this operation, 31.6 MB of additional disk space will be used.
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 6.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libarchive-dev:amd64.
# (Reading database ... 123624 files and directories currently installed.)
# Preparing to unpack .../0-libarchive-dev_3.6.0-1ubuntu1.3_amd64.deb ...
# Unpacking libarchive-dev:amd64 (3.6.0-1ubuntu1.3) ...
# Selecting previously unselected package libleptonica-dev.
# Preparing to unpack .../1-libleptonica-dev_1.82.0-3build1_amd64.deb ...
# Unpacking libleptonica-dev (1.82.0-3build1) ...
# Selecting previously unselected package libtesseract-dev:amd64.
# Preparing to unpack .../2-libtesseract-dev_4.1.1-2.1build1_amd64.deb ...
# Unpacking libtesseract-dev:amd64 (4.1.1-2.1build1) ...
# Selecting previously unselected package tesseract-ocr-eng.
# Preparing to unpack .../3-tesseract-ocr-eng_1%3a4.00~git30-7274cfa-1.1_all.deb ...
# Unpacking tesseract-ocr-eng (1:4.00~git30-7274cfa-1.1) ...
# Selecting previously unselected package tesseract-ocr-osd.
# Preparing to unpack .../4-tesseract-ocr-osd_1%3a4.00~git30-7274cfa-1.1_all.deb ...
# Unpacking tesseract-ocr-osd (1:4.00~git30-7274cfa-1.1) ...
# Selecting previously unselected package tesseract-ocr.
# Preparing to unpack .../5-tesseract-ocr_4.1.1-2.1build1_amd64.deb ...
# Unpacking tesseract-ocr (4.1.1-2.1build1) ...
# Setting up tesseract-ocr-eng (1:4.00~git30-7274cfa-1.1) ...
# Setting up libleptonica-dev (1.82.0-3build1) ...
# Setting up libarchive-dev:amd64 (3.6.0-1ubuntu1.3) ...
# Setting up tesseract-ocr-osd (1:4.00~git30-7274cfa-1.1) ...
# Setting up libtesseract-dev:amd64 (4.1.1-2.1build1) ...
# Setting up tesseract-ocr (4.1.1-2.1build1) ...
# Processing triggers for man-db (2.10.2-1) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 29.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-droid-fallback.
# (Reading database ... 123804 files and directories currently installed.)
# Preparing to unpack .../00-fonts-droid-fallback_1%3a6.0.1r16-1.1build1_all.deb ...
# Unpacking fonts-droid-fallback (1:6.0.1r16-1.1build1) ...
# Selecting previously unselected package poppler-data.
# Preparing to unpack .../01-poppler-data_0.4.11-1_all.deb ...
# Unpacking poppler-data (0.4.11-1) ...
# Selecting previously unselected package antiword.
# Preparing to unpack .../02-antiword_0.37-16_amd64.deb ...
# Unpacking antiword (0.37-16) ...
# Selecting previously unselected package flac.
# Preparing to unpack .../03-flac_1.3.3-2ubuntu0.2_amd64.deb ...
# Unpacking flac (1.3.3-2ubuntu0.2) ...
# Selecting previously unselected package fonts-noto-mono.
# Preparing to unpack .../04-fonts-noto-mono_20201225-1build1_all.deb ...
# Unpacking fonts-noto-mono (20201225-1build1) ...
# Selecting previously unselected package fonts-urw-base35.
# Preparing to unpack .../05-fonts-urw-base35_20200910-1_all.deb ...
# Unpacking fonts-urw-base35 (20200910-1) ...
# Selecting previously unselected package libgs9-common.
# Preparing to unpack .../06-libgs9-common_9.55.0~dfsg1-0ubuntu5.9_all.deb ...
# Unpacking libgs9-common (9.55.0~dfsg1-0ubuntu5.9) ...
# Selecting previously unselected package libidn12:amd64.
# Preparing to unpack .../07-libidn12_1.38-4ubuntu1_amd64.deb ...
# Unpacking libidn12:amd64 (1.38-4ubuntu1) ...
# Selecting previously unselected package libijs-0.35:amd64.
# Preparing to unpack .../08-libijs-0.35_0.35-15build2_amd64.deb ...
# Unpacking libijs-0.35:amd64 (0.35-15build2) ...
# Selecting previously unselected package libjbig2dec0:amd64.
# Preparing to unpack .../09-libjbig2dec0_0.19-3build2_amd64.deb ...
# Unpacking libjbig2dec0:amd64 (0.19-3build2) ...
# Selecting previously unselected package libgs9:amd64.
# Preparing to unpack .../10-libgs9_9.55.0~dfsg1-0ubuntu5.9_amd64.deb ...
# Unpacking libgs9:amd64 (9.55.0~dfsg1-0ubuntu5.9) ...
# Selecting previously unselected package ghostscript.
# Preparing to unpack .../11-ghostscript_9.55.0~dfsg1-0ubuntu5.9_amd64.deb ...
# Unpacking ghostscript (9.55.0~dfsg1-0ubuntu5.9) ...
# Selecting previously unselected package lame.
# Preparing to unpack .../12-lame_3.100-3build2_amd64.deb ...
# Unpacking lame (3.100-3build2) ...
# Selecting previously unselected package libid3tag0:amd64.
# Preparing to unpack .../13-libid3tag0_0.15.1b-14_amd64.deb ...
# Unpacking libid3tag0:amd64 (0.15.1b-14) ...
# Selecting previously unselected package libmad0:amd64.
# Preparing to unpack .../14-libmad0_0.15.1b-10ubuntu1_amd64.deb ...
# Unpacking libmad0:amd64 (0.15.1b-10ubuntu1) ...
# Selecting previously unselected package libopencore-amrnb0:amd64.
# Preparing to unpack .../15-libopencore-amrnb0_0.1.5-1_amd64.deb ...
# Unpacking libopencore-amrnb0:amd64 (0.1.5-1) ...
# Selecting previously unselected package libopencore-amrwb0:amd64.
# Preparing to unpack .../16-libopencore-amrwb0_0.1.5-1_amd64.deb ...
# Unpacking libopencore-amrwb0:amd64 (0.1.5-1) ...
# Selecting previously unselected package libsox3:amd64.
# Preparing to unpack .../17-libsox3_14.4.2+git20190427-2+deb11u2ubuntu0.22.04.1_amd64.deb ...
# Unpacking libsox3:amd64 (14.4.2+git20190427-2+deb11u2ubuntu0.22.04.1) ...
# Selecting previously unselected package libsox-fmt-alsa:amd64.
# Preparing to unpack .../18-libsox-fmt-alsa_14.4.2+git20190427-2+deb11u2ubuntu0.22.04.1_amd64.deb ...
# Unpacking libsox-fmt-alsa:amd64 (14.4.2+git20190427-2+deb11u2ubuntu0.22.04.1) ...
# Selecting previously unselected package libwavpack1:amd64.
# Preparing to unpack .../19-libwavpack1_5.4.0-1build2_amd64.deb ...
# Unpacking libwavpack1:amd64 (5.4.0-1build2) ...
# Selecting previously unselected package libsox-fmt-base:amd64.
# Preparing to unpack .../20-libsox-fmt-base_14.4.2+git20190427-2+deb11u2ubuntu0.22.04.1_amd64.deb ...
# Unpacking libsox-fmt-base:amd64 (14.4.2+git20190427-2+deb11u2ubuntu0.22.04.1) ...
# Selecting previously unselected package libsox-fmt-mp3:amd64.
# Preparing to unpack .../21-libsox-fmt-mp3_14.4.2+git20190427-2+deb11u2ubuntu0.22.04.1_amd64.deb ...
# Unpacking libsox-fmt-mp3:amd64 (14.4.2+git20190427-2+deb11u2ubuntu0.22.04.1) ...
# Selecting previously unselected package libxslt1-dev:amd64.
# Preparing to unpack .../22-libxslt1-dev_1.1.34-4ubuntu0.22.04.1_amd64.deb ...
# Unpacking libxslt1-dev:amd64 (1.1.34-4ubuntu0.22.04.1) ...
# Selecting previously unselected package poppler-utils.
# Preparing to unpack .../23-poppler-utils_22.02.0-2ubuntu0.5_amd64.deb ...
# Unpacking poppler-utils (22.02.0-2ubuntu0.5) ...
# Selecting previously unselected package pstotext.
# Preparing to unpack .../24-pstotext_1.9-6build1_amd64.deb ...
# Unpacking pstotext (1.9-6build1) ...
# Selecting previously unselected package sox.
# Preparing to unpack .../25-sox_14.4.2+git20190427-2+deb11u2ubuntu0.22.04.1_amd64.deb ...
# Unpacking sox (14.4.2+git20190427-2+deb11u2ubuntu0.22.04.1) ...
# Selecting previously unselected package swig4.0.
# Preparing to unpack .../26-swig4.0_4.0.2-1ubuntu1_amd64.deb ...
# Unpacking swig4.0 (4.0.2-1ubuntu1) ...
# Selecting previously unselected package swig.
# Preparing to unpack .../27-swig_4.0.2-1ubuntu1_all.deb ...
# Unpacking swig (4.0.2-1ubuntu1) ...
# Selecting previously unselected package unrtf.
# Preparing to unpack .../28-unrtf_0.21.10-clean-1_amd64.deb ...
# Unpacking unrtf (0.21.10-clean-1) ...
# Setting up unrtf (0.21.10-clean-1) ...
# Setting up libxslt1-dev:amd64 (1.1.34-4ubuntu0.22.04.1) ...
# Setting up fonts-noto-mono (20201225-1build1) ...
# Setting up libsox3:amd64 (14.4.2+git20190427-2+deb11u2ubuntu0.22.04.1) ...
# Setting up libijs-0.35:amd64 (0.35-15build2) ...
# Setting up fonts-urw-base35 (20200910-1) ...
# Setting up lame (3.100-3build2) ...
# Setting up poppler-data (0.4.11-1) ...
# Setting up libid3tag0:amd64 (0.15.1b-14) ...
# Setting up libopencore-amrwb0:amd64 (0.1.5-1) ...
# Setting up flac (1.3.3-2ubuntu0.2) ...
# Setting up libjbig2dec0:amd64 (0.19-3build2) ...
# Setting up libidn12:amd64 (1.38-4ubuntu1) ...
# Setting up libsox-fmt-alsa:amd64 (14.4.2+git20190427-2+deb11u2ubuntu0.22.04.1) ...
# Setting up libmad0:amd64 (0.15.1b-10ubuntu1) ...
# Setting up libwavpack1:amd64 (5.4.0-1build2) ...
# Setting up libopencore-amrnb0:amd64 (0.1.5-1) ...
# Setting up antiword (0.37-16) ...
# Setting up libsox-fmt-base:amd64 (14.4.2+git20190427-2+deb11u2ubuntu0.22.04.1) ...
# Setting up fonts-droid-fallback (1:6.0.1r16-1.1build1) ...
# Setting up poppler-utils (22.02.0-2ubuntu0.5) ...
# Setting up swig4.0 (4.0.2-1ubuntu1) ...
# Setting up libsox-fmt-mp3:amd64 (14.4.2+git20190427-2+deb11u2ubuntu0.22.04.1) ...
# Setting up libgs9-common (9.55.0~dfsg1-0ubuntu5.9) ...
# Setting up swig (4.0.2-1ubuntu1) ...
# Setting up libgs9:amd64 (9.55.0~dfsg1-0ubuntu5.9) ...
# Setting up ghostscript (9.55.0~dfsg1-0ubuntu5.9) ...
# Setting up sox (14.4.2+git20190427-2+deb11u2ubuntu0.22.04.1) ...
# Setting up pstotext (1.9-6build1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# Requirement already satisfied: langchain in /usr/local/lib/python3.10/dist-packages (0.3.7)
# Collecting langchain-community
#   Downloading langchain_community-0.3.5-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (3.10.10)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (4.0.3)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.15 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.3.15)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.3.2)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.1.139)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.9.2)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (9.0.0)
# Collecting SQLAlchemy<3,>=1.4 (from langchain)
#   Downloading SQLAlchemy-2.0.35-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.6 kB)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting httpx-sse<0.5.0,>=0.4.0 (from langchain-community)
#   Downloading httpx_sse-0.4.0-py3-none-any.whl.metadata (9.0 kB)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain-community)
#   Downloading pydantic_settings-2.6.1-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.17.1)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading marshmallow-3.23.1-py3-none-any.whl.metadata (7.5 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.15->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.15->langchain) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.15->langchain) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.17->langchain) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.11)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.23.4)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.4.0->langchain-community)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (3.7.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.0.6)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.15->langchain) (3.0.0)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.3->langchain) (0.2.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.2.2)
# Downloading langchain_community-0.3.5-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 23.9 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Downloading pydantic_settings-2.6.1-py3-none-any.whl (28 kB)
# Downloading SQLAlchemy-2.0.35-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 57.0 MB/s eta 0:00:00
# Downloading marshmallow-3.23.1-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 4.8 MB/s eta 0:00:00
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: SQLAlchemy, python-dotenv, mypy-extensions, marshmallow, httpx-sse, typing-inspect, pydantic-settings, dataclasses-json, langchain-community
#   Attempting uninstall: SQLAlchemy
#     Found existing installation: SQLAlchemy 2.0.36
#     Uninstalling SQLAlchemy-2.0.36:
#       Successfully uninstalled SQLAlchemy-2.0.36
# Successfully installed SQLAlchemy-2.0.35 dataclasses-json-0.6.7 httpx-sse-0.4.0 langchain-community-0.3.5 marshmallow-3.23.1 mypy-extensions-1.0.0 pydantic-settings-2.6.1 python-dotenv-1.0.1 typing-inspect-0.9.0

# %%
import urllib
import warnings
from pathlib import Path as p
from pprint import pprint

import pandas as pd
from langchain import PromptTemplate
from langchain.chains.question_answering import load_qa_chain
from langchain.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores import Chroma
from langchain.chains import RetrievalQA



warnings.filterwarnings("ignore")
# restart python kernal if issues with langchain import.

# %%
# !pip install --upgrade google-generativeai
# Out:
# Requirement already satisfied: google-generativeai in /usr/local/lib/python3.10/dist-packages (0.8.3)
# Requirement already satisfied: google-ai-generativelanguage==0.6.10 in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (0.6.10)
# Requirement already satisfied: google-api-core in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (2.19.2)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (2.137.0)
# Requirement already satisfied: google-auth>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (2.27.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (3.20.3)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (2.9.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (4.66.6)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (4.12.2)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from google-ai-generativelanguage==0.6.10->google-generativeai) (1.25.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core->google-generativeai) (1.65.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /usr/local/lib/python3.10/dist-packages (from google-api-core->google-generativeai) (2.32.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=2.15.0->google-generativeai) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth>=2.15.0->google-generativeai) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth>=2.15.0->google-generativeai) (4.9)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client->google-generativeai) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client->google-generativeai) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client->google-generativeai) (4.1.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic->google-generativeai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic->google-generativeai) (2.23.4)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.10->google-generativeai) (1.64.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.10->google-generativeai) (1.48.2)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client->google-generativeai) (3.2.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (2024.8.30)

# %%
# !pip install langchain-google-genai
# Out:
# Collecting langchain-google-genai
#   Downloading langchain_google_genai-2.0.4-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: google-generativeai<0.9.0,>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from langchain-google-genai) (0.8.3)
# Requirement already satisfied: langchain-core<0.4,>=0.3.15 in /usr/local/lib/python3.10/dist-packages (from langchain-google-genai) (0.3.15)
# Requirement already satisfied: pydantic<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain-google-genai) (2.9.2)
# Requirement already satisfied: google-ai-generativelanguage==0.6.10 in /usr/local/lib/python3.10/dist-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (0.6.10)
# Requirement already satisfied: google-api-core in /usr/local/lib/python3.10/dist-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (2.19.2)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.10/dist-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (2.137.0)
# Requirement already satisfied: google-auth>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (2.27.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (3.20.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (4.66.6)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (4.12.2)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from google-ai-generativelanguage==0.6.10->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (1.25.0)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4,>=0.3.15->langchain-google-genai) (6.0.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4,>=0.3.15->langchain-google-genai) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.125 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4,>=0.3.15->langchain-google-genai) (0.1.139)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4,>=0.3.15->langchain-google-genai) (24.1)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4,>=0.3.15->langchain-google-genai) (9.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=2->langchain-google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=2->langchain-google-genai) (2.23.4)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (1.65.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /usr/local/lib/python3.10/dist-packages (from google-api-core->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (2.32.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=2.15.0->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth>=2.15.0->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth>=2.15.0->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (4.9)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4,>=0.3.15->langchain-google-genai) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3.15->langchain-google-genai) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3.15->langchain-google-genai) (3.10.11)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3.15->langchain-google-genai) (1.0.0)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (4.1.1)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.10->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (1.64.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.10->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (1.48.2)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (3.2.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3.15->langchain-google-genai) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3.15->langchain-google-genai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3.15->langchain-google-genai) (1.0.6)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3.15->langchain-google-genai) (3.10)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3.15->langchain-google-genai) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3.15->langchain-google-genai) (0.14.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (2.2.3)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3.15->langchain-google-genai) (1.2.2)
# Downloading langchain_google_genai-2.0.4-py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 1.5 MB/s eta 0:00:00
# Installing collected packages: langchain-google-genai
# Successfully installed langchain-google-genai-2.0.4

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
# !pip install chromadb python-dotenv
# Out:
# Collecting chromadb
#   Downloading chromadb-0.5.18-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.10/dist-packages (1.0.1)
# Collecting build>=1.0.3 (from chromadb)
#   Downloading build-1.2.2.post1-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: pydantic>=1.9 in /usr/local/lib/python3.10/dist-packages (from chromadb) (2.9.2)
# Collecting chroma-hnswlib==0.7.6 (from chromadb)
#   Downloading chroma_hnswlib-0.7.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (252 bytes)
# Collecting fastapi>=0.95.2 (from chromadb)
#   Downloading fastapi-0.115.4-py3-none-any.whl.metadata (27 kB)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading uvicorn-0.32.0-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: numpy>=1.22.5 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.26.4)
# Collecting posthog>=2.4.0 (from chromadb)
#   Downloading posthog-3.7.0-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (4.12.2)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Downloading onnxruntime-1.20.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.28.0)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.28.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0 (from chromadb)
#   Downloading opentelemetry_instrumentation_fastapi-0.49b1-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.28.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.19.1)
# Collecting pypika>=0.48.9 (from chromadb)
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 3.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (4.66.6)
# Collecting overrides>=7.3.1 (from chromadb)
#   Downloading overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from chromadb) (6.4.5)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.64.1)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Downloading bcrypt-4.2.0-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (9.6 kB)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.12.5)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Downloading kubernetes-31.0.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: tenacity>=8.2.3 in /usr/local/lib/python3.10/dist-packages (from chromadb) (9.0.0)
# Requirement already satisfied: PyYAML>=6.0.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (6.0.2)
# Collecting mmh3>=4.0.1 (from chromadb)
#   Downloading mmh3-5.0.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (14 kB)
# Requirement already satisfied: orjson>=3.9.12 in /usr/local/lib/python3.10/dist-packages (from chromadb) (3.10.11)
# Requirement already satisfied: httpx>=0.27.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.27.2)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (13.9.4)
# Requirement already satisfied: packaging>=19.1 in /usr/local/lib/python3.10/dist-packages (from build>=1.0.3->chromadb) (24.1)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb)
#   Downloading pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from build>=1.0.3->chromadb) (2.0.2)
# Collecting starlette<0.42.0,>=0.40.0 (from fastapi>=0.95.2->chromadb)
#   Downloading starlette-0.41.2-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.27.0->chromadb) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.27.0->chromadb) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx>=0.27.0->chromadb) (1.0.6)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx>=0.27.0->chromadb) (3.10)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.27.0->chromadb) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Requirement already satisfied: google-auth>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (2.27.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (2.32.3)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (1.3.1)
# Requirement already satisfied: oauthlib>=3.2.2 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (2.2.3)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb)
#   Downloading durationpy-0.9-py3-none-any.whl.metadata (338 bytes)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb) (24.3.25)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb) (3.20.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb) (1.13.1)
# Requirement already satisfied: deprecated>=1.2.6 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.14)
# Requirement already satisfied: importlib-metadata<=8.5.0,>=6.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-api>=1.2.0->chromadb) (8.5.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.65.0)
# Collecting opentelemetry-exporter-otlp-proto-common==1.28.1 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.28.1-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-proto==1.28.1 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_proto-1.28.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb)
#   Downloading opentelemetry_sdk-1.28.1-py3-none-any.whl.metadata (1.5 kB)
# Collecting protobuf (from onnxruntime>=1.14.1->chromadb)
#   Downloading protobuf-5.28.3-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Collecting opentelemetry-instrumentation-asgi==0.49b1 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_instrumentation_asgi-0.49b1-py3-none-any.whl.metadata (2.0 kB)
# Collecting opentelemetry-instrumentation==0.49b1 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_instrumentation-0.49b1-py3-none-any.whl.metadata (6.2 kB)
# Collecting opentelemetry-semantic-conventions==0.49b1 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_semantic_conventions-0.49b1-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-util-http==0.49b1 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_util_http-0.49b1-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation==0.49b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.16.0)
# Collecting asgiref~=3.0 (from opentelemetry-instrumentation-asgi==0.49b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading asgiref-3.8.1-py3-none-any.whl.metadata (9.3 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb)
#   Downloading opentelemetry_api-1.28.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb)
#   Downloading monotonic-1.6-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting backoff>=1.10.0 (from posthog>=2.4.0->chromadb)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.9->chromadb) (2.23.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->chromadb) (2.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from tokenizers>=0.13.2->chromadb) (0.24.7)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Collecting httptools>=0.5.0 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading httptools-0.6.4-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading uvloop-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading watchfiles-0.24.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading websockets-14.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2024.10.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata<=8.5.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.20.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kubernetes>=28.1.0->chromadb) (3.4.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx>=0.27.0->chromadb) (1.2.2)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# Downloading chromadb-0.5.18-py3-none-any.whl (615 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 615.5/615.5 kB 14.1 MB/s eta 0:00:00
# Downloading chroma_hnswlib-0.7.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 50.4 MB/s eta 0:00:00
# Downloading bcrypt-4.2.0-cp39-abi3-manylinux_2_28_x86_64.whl (273 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 273.8/273.8 kB 24.1 MB/s eta 0:00:00
# Downloading build-1.2.2.post1-py3-none-any.whl (22 kB)
# Downloading fastapi-0.115.4-py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.7/94.7 kB 9.4 MB/s eta 0:00:00
# Downloading kubernetes-31.0.0-py2.py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 71.2 MB/s eta 0:00:00
# Downloading mmh3-5.0.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (93 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.2/93.2 kB 7.9 MB/s eta 0:00:00
# Downloading onnxruntime-1.20.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (13.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 89.2 MB/s eta 0:00:00
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.28.1-py3-none-any.whl (18 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.28.1-py3-none-any.whl (18 kB)
# Downloading opentelemetry_proto-1.28.1-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 5.0 MB/s eta 0:00:00
# Downloading opentelemetry_instrumentation_fastapi-0.49b1-py3-none-any.whl (12 kB)
# Downloading opentelemetry_instrumentation-0.49b1-py3-none-any.whl (30 kB)
# Downloading opentelemetry_instrumentation_asgi-0.49b1-py3-none-any.whl (16 kB)
# Downloading opentelemetry_semantic_conventions-0.49b1-py3-none-any.whl (159 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.2/159.2 kB 16.4 MB/s eta 0:00:00
# Downloading opentelemetry_api-1.28.1-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.3/64.3 kB 6.1 MB/s eta 0:00:00
# Downloading opentelemetry_util_http-0.49b1-py3-none-any.whl (6.9 kB)
# Downloading opentelemetry_sdk-1.28.1-py3-none-any.whl (118 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.7/118.7 kB 12.1 MB/s eta 0:00:00
# Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading posthog-3.7.0-py2.py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.4/54.4 kB 5.0 MB/s eta 0:00:00
# Downloading uvicorn-0.32.0-py3-none-any.whl (63 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 6.2 MB/s eta 0:00:00
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading durationpy-0.9-py3-none-any.whl (3.5 kB)
# Downloading httptools-0.6.4-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (442 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.1/442.1 kB 35.0 MB/s eta 0:00:00
# Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Downloading protobuf-5.28.3-cp38-abi3-manylinux2014_x86_64.whl (316 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.6/316.6 kB 26.6 MB/s eta 0:00:00
# Downloading starlette-0.41.2-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.3/73.3 kB 7.5 MB/s eta 0:00:00
# Downloading uvloop-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 79.7 MB/s eta 0:00:00
# Downloading watchfiles-0.24.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (425 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 425.7/425.7 kB 35.5 MB/s eta 0:00:00
# Downloading websockets-14.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (167 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.5/167.5 kB 14.9 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.4 MB/s eta 0:00:00
# Downloading pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Downloading asgiref-3.8.1-py3-none-any.whl (23 kB)
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 8.6 MB/s eta 0:00:00
# Building wheels for collected packages: pypika
#   Building wheel for pypika (pyproject.toml) ... done
#   Created wheel for pypika: filename=PyPika-0.48.9-py2.py3-none-any.whl size=53725 sha256=2756a293d88311cdcbcda2eac09d4f9a34f4ffe59b2af84d359fa38f1aa1304d
#   Stored in directory: /root/.cache/pip/wheels/e1/26/51/d0bffb3d2fd82256676d7ad3003faea3bd6dddc9577af665f4
# Successfully built pypika
# Installing collected packages: pypika, monotonic, durationpy, websockets, uvloop, uvicorn, pyproject_hooks, protobuf, overrides, opentelemetry-util-http, mmh3, humanfriendly, httptools, chroma-hnswlib, bcrypt, backoff, asgiref, watchfiles, starlette, posthog, opentelemetry-proto, opentelemetry-api, coloredlogs, build, opentelemetry-semantic-conventions, opentelemetry-exporter-otlp-proto-common, onnxruntime, kubernetes, fastapi, opentelemetry-sdk, opentelemetry-instrumentation, opentelemetry-instrumentation-asgi, opentelemetry-exporter-otlp-proto-grpc, opentelemetry-instrumentation-fastapi, chromadb
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: opentelemetry-api
#     Found existing installation: opentelemetry-api 1.28.0
#     Uninstalling opentelemetry-api-1.28.0:
#       Successfully uninstalled opentelemetry-api-1.28.0
#   Attempting uninstall: opentelemetry-semantic-conventions
#     Found existing installation: opentelemetry-semantic-conventions 0.49b0
#     Uninstalling opentelemetry-semantic-conventions-0.49b0:
#       Successfully uninstalled opentelemetry-semantic-conventions-0.49b0
#   Attempting uninstall: opentelemetry-sdk
#     Found existing installation: opentelemetry-sdk 1.28.0
#     Uninstalling opentelemetry-sdk-1.28.0:
#       Successfully uninstalled opentelemetry-sdk-1.28.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-cloud-datastore 2.19.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 5.28.3 which is incompatible.
# google-cloud-firestore 2.16.1 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 5.28.3 which is incompatible.
# tensorboard 2.17.0 requires protobuf!=4.24.0,<5.0.0,>=3.19.6, but you have protobuf 5.28.3 which is incompatible.
# tensorflow 2.17.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 5.28.3 which is incompatible.
# tensorflow-metadata 1.16.1 requires protobuf<4.21,>=3.20.3; python_version < "3.11", but you have protobuf 5.28.3 which is incompatible.
# Successfully installed asgiref-3.8.1 backoff-2.2.1 bcrypt-4.2.0 build-1.2.2.post1 chroma-hnswlib-0.7.6 chromadb-0.5.18 coloredlogs-15.0.1 durationpy-0.9 fastapi-0.115.4 httptools-0.6.4 humanfriendly-10.0 kubernetes-31.0.0 mmh3-5.0.1 monotonic-1.6 onnxruntime-1.20.0 opentelemetry-api-1.28.1 opentelemetry-exporter-otlp-proto-common-1.28.1 opentelemetry-exporter-otlp-proto-grpc-1.28.1 opentelemetry-instrumentation-0.49b1 opentelemetry-instrumentation-asgi-0.49b1 opentelemetry-instrumentation-fastapi-0.49b1 opentelemetry-proto-1.28.1 opentelemetry-sdk-1.28.1 opentelemetry-semantic-conventions-0.49b1 opentelemetry-util-http-0.49b1 overrides-7.7.0 posthog-3.7.0 protobuf-5.28.3 pypika-0.48.9 pyproject_hooks-1.2.0 starlette-0.41.2 uvicorn-0.32.0 uvloop-0.21.0 watchfiles-0.24.0 websockets-14.0

# %%
from google.colab import userdata
# The gemini api key
GOOGLE_API_KEY = userdata.get('GOOGLE_API_KEY')
print(GOOGLE_API_KEY)
# Out:
# AIzaSyAsdJzG-XslY5w7i7aHWijyd3iLa4ElgPg

# %%
model = ChatGoogleGenerativeAI(model="gemini-pro",google_api_key=GOOGLE_API_KEY,
                             temperature=0.2,convert_system_message_to_human=True)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install pypdf
# Out:
# Collecting pypdf
#   Downloading pypdf-5.1.0-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: typing_extensions>=4.0 in /usr/local/lib/python3.10/dist-packages (from pypdf) (4.12.2)
# Downloading pypdf-5.1.0-py3-none-any.whl (297 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 kB 4.0 MB/s eta 0:00:00
# Installing collected packages: pypdf
# Successfully installed pypdf-5.1.0

# %%
import os
from langchain.document_loaders import PyPDFLoader

# Chemin du dossier principal contenant les fichiers PDF
root_folder = '/content/drive/MyDrive/Accreditation'  # Remplacez avec le chemin vers votre dossier

# Liste pour stocker le contenu de tous les PDFs
all_pages = []

# Parcourir tous les fichiers PDF dans le dossier racine
for filename in os.listdir(root_folder):
    if filename.lower().endswith('.pdf'):  # Vérifie si le fichier est un PDF
        pdf_path = os.path.join(root_folder, filename)
        print(f"Chargement du fichier PDF : {pdf_path}")

        try:
            # Charger le PDF avec PyPDFLoader et diviser en pages
            pdf_loader = PyPDFLoader(pdf_path)
            pages = pdf_loader.load_and_split()

            # Ajouter toutes les pages du PDF à la liste all_pages
            all_pages.extend(pages)
            print(f"Ajouté {len(pages)} pages de {filename}.")

        except Exception as e:
            print(f"Erreur lors du chargement de {filename}: {e}")

# Afficher un aperçu des pages extraites
for i, page in enumerate(all_pages[:5]):  # Affiche les 5 premières pages pour un aperçu
    print(f"Page {i+1} :\n{page.page_content}\n{'-' * 40}")
# Out:
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/RAE_CTI_ISI_19.02.2024.pdf
# Ajouté 70 pages de RAE_CTI_ISI_19.02.2024.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/annexeG_enquete_insertion(1).pdf
# WARNING:pypdf._reader:Ignoring wrong pointing object 21 0 (offset 0)
# Ajouté 8 pages de annexeG_enquete_insertion(1).pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/annexeG_enquete_insertion.pdf
# WARNING:pypdf._reader:Ignoring wrong pointing object 21 0 (offset 0)
# Ajouté 8 pages de annexeG_enquete_insertion.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/IBM_Higher Institute of Computer Science_Tunisia_Extension - Fully Sigend 020223.pdf
# Ajouté 1 pages de IBM_Higher Institute of Computer Science_Tunisia_Extension - Fully Sigend 020223.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/Huawei.pdf
# Ajouté 1 pages de Huawei.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/CiscoAgreement.pdf
# Ajouté 2 pages de CiscoAgreement.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/annexeG5Certif.pdf
# Ajouté 4 pages de annexeG5Certif.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/AnnexeG_Rapport_activites_centre_4C.pdf
# Ajouté 4 pages de AnnexeG_Rapport_activites_centre_4C.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/Répartition du nombre de PFE durant les trois dernières années pour chaque filière (4).pdf
# Ajouté 1 pages de Répartition du nombre de PFE durant les trois dernières années pour chaque filière (4).pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/AnnexeC_Plan_PROCESSUSgestion de stages et PFE_ISo21001GSP-PP-05-plan processus GSP version181023.pdf
# Ajouté 14 pages de AnnexeC_Plan_PROCESSUSgestion de stages et PFE_ISo21001GSP-PP-05-plan processus GSP version181023.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/Autres enquetes et Actions.pdf
# Ajouté 15 pages de Autres enquetes et Actions.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/F.2 texte de loi inscription des étudiants étrangers.pdf
# Ajouté 1 pages de F.2 texte de loi inscription des étudiants étrangers.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/F.1 guide étudiant.pdf
# Ajouté 17 pages de F.1 guide étudiant.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/Processus de Recrutement du Leader et Formation du Core Team pour Google DSC ISI Ariana.pdf
# Ajouté 1 pages de Processus de Recrutement du Leader et Formation du Core Team pour Google DSC ISI Ariana.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/Processus d_Élection Freeways ISI 2023.pdf
# Ajouté 4 pages de Processus d_Élection Freeways ISI 2023.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/JCI ISI Ariana.pdf
# Ajouté 2 pages de JCI ISI Ariana.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/election-geeks.pdf
# Ajouté 1 pages de election-geeks.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/Election Creative Lab 2023_2024.pdf
# Ajouté 4 pages de Election Creative Lab 2023_2024.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/Règlement intérieur ENACTUS ISI.pdf
# Ajouté 12 pages de Règlement intérieur ENACTUS ISI.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/Rapport_Securinets_ISI.pdf
# Ajouté 6 pages de Rapport_Securinets_ISI.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/Rapport D_activité -Hult Prize ISI Ariana.pdf
# Ajouté 2 pages de Rapport D_activité -Hult Prize ISI Ariana.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/Rapport club DSC_ISI .pdf
# Ajouté 2 pages de Rapport club DSC_ISI .pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/Rapport ArtBox ISI.pdf
# Ajouté 12 pages de Rapport ArtBox ISI.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/Rapport activités nationales IEEE ISI.pdf
# Ajouté 5 pages de Rapport activités nationales IEEE ISI.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/Freeways ISI.pdf
# Ajouté 10 pages de Freeways ISI.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/Dossier_d’accréditation_Codex_JE.pdf
# Ajouté 3 pages de Dossier_d’accréditation_Codex_JE.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/Annexe E.8.pdf
# Ajouté 7 pages de Annexe E.8.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/Annexe E.7.pdf
# Ajouté 0 pages de Annexe E.7.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/Annexe E.6.pdf
# Ajouté 0 pages de Annexe E.6.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/Annexe E.5.pdf
# Ajouté 3 pages de Annexe E.5.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/Annexe E.1.pdf
# Ajouté 47 pages de Annexe E.1.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/Annexe E.2.pdf
# Ajouté 0 pages de Annexe E.2.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/Annexe E.3.pdf
# Ajouté 0 pages de Annexe E.3.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/Annexe E.4.pdf
# Ajouté 4 pages de Annexe E.4.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/D.8 Textes JO00296 Régime des études ING p.9-10.pdf
# Ajouté 47 pages de D.8 Textes JO00296 Régime des études ING p.9-10.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/D.1 Etude IFC & UTICA.pdf
# Ajouté 47 pages de D.1 Etude IFC & UTICA.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/Calendrier 2023-2024.pdf
# Ajouté 3 pages de Calendrier 2023-2024.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/Calendrier 2022-2023.pdf
# Ajouté 3 pages de Calendrier 2022-2023.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/F.1 guide étudiant (1).pdf
# Ajouté 17 pages de F.1 guide étudiant (1).pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/Calendrier 2023-2024 (1).pdf
# Ajouté 3 pages de Calendrier 2023-2024 (1).pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/Calendrier 2022-2023 (1).pdf
# Ajouté 3 pages de Calendrier 2022-2023 (1).pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/PV GEII Equipes Pédagogiques 2023_S2.pdf
# Ajouté 0 pages de PV GEII Equipes Pédagogiques 2023_S2.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/PV GEII Equipes Pédagogiques 2023_S1.pdf
# Ajouté 0 pages de PV GEII Equipes Pédagogiques 2023_S1.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/PV GEII de département 2023-2024.pdf
# Ajouté 0 pages de PV GEII de département 2023-2024.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/PV GEII de département 2022-2023.pdf
# Ajouté 0 pages de PV GEII de département 2022-2023.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/Process équipes pédagogiques par spécialité & par module - DE - Septembre 2022.pdf
# Ajouté 7 pages de Process équipes pédagogiques par spécialité & par module - DE - Septembre 2022.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/D.8 Textes JO00296 Régime des études ING p.9-10 (1).pdf
# Ajouté 47 pages de D.8 Textes JO00296 Régime des études ING p.9-10 (1).pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/D.1 Etude IFC & UTICA (1).pdf
# Ajouté 47 pages de D.1 Etude IFC & UTICA (1).pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/Annexe C. plan processus gestion des stages.pdf
# Ajouté 14 pages de Annexe C. plan processus gestion des stages.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/Annexe C.4 Visites Entreprises.pdf
# Ajouté 1 pages de Annexe C.4 Visites Entreprises.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/Annexe C.6 Journée_Orientation.pdf
# Ajouté 1 pages de Annexe C.6 Journée_Orientation.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/fiche-1-6_2024-02-08-10-26-10.pdf
# Ajouté 1 pages de fiche-1-6_2024-02-08-10-26-10.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/Annexe C.8 Rayonnement international - Prof visiteurs.pdf
# Ajouté 2 pages de Annexe C.8 Rayonnement international - Prof visiteurs.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/PV selection ISI.pdf
# Ajouté 0 pages de PV selection ISI.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/Att-Hammami.pdf
# Ajouté 0 pages de Att-Hammami.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/WEVIOO.pdf
# Ajouté 0 pages de WEVIOO.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/Telnet.pdf
# Ajouté 0 pages de Telnet.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/SAMA Partners ISI.pdf
# Ajouté 0 pages de SAMA Partners ISI.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/Partenariat NEXT STEP.pdf
# Ajouté 0 pages de Partenariat NEXT STEP.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/Convention de Partenariat SOFRECOM.pdf
# Ajouté 0 pages de Convention de Partenariat SOFRECOM.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/Convention ISI_Aiventu.pdf
# Ajouté 0 pages de Convention ISI_Aiventu.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/convention Vneuron.pdf
# Ajouté 0 pages de convention Vneuron.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/Higher Inst Skills Academy Agmt S2178061 PE July 6, 2021 copy.pdf
# Ajouté 0 pages de Higher Inst Skills Academy Agmt S2178061 PE July 6, 2021 copy.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/LINE-DATA.pdf
# Ajouté 0 pages de LINE-DATA.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/Convention de Partenariat DOCAPOSTE.pdf
# Ajouté 0 pages de Convention de Partenariat DOCAPOSTE.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/Capgemini.pdf
# Ajouté 0 pages de Capgemini.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/AXEFINANCE.pdf
# Ajouté 0 pages de AXEFINANCE.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/ACCTIA.pdf
# Ajouté 0 pages de ACCTIA.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/C.2.pdf
# Ajouté 2 pages de C.2.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/convention d_application Paris13.pdf
# Ajouté 0 pages de convention d_application Paris13.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/Bourses etranger - en arabe.pdf
# Ajouté 0 pages de Bourses etranger - en arabe.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/Annexe B.12 TDR organisme certificateur.pdf
# Ajouté 0 pages de Annexe B.12 TDR organisme certificateur.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/Annexe B.11 Rapport_diagnostic_initial_21001.pdf
# Ajouté 22 pages de Annexe B.11 Rapport_diagnostic_initial_21001.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/Annexe B.10 TDR (Mission assistance technique SMOE ISO21001).pdf
# Ajouté 13 pages de Annexe B.10 TDR (Mission assistance technique SMOE ISO21001).pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/Annexe B.8 Proposition Complète Projet PAQ RISE.pdf
# Ajouté 59 pages de Annexe B.8 Proposition Complète Projet PAQ RISE.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/Annexe B.7 RAE_ISI_IEAQA_AQU MED.pdf
# Ajouté 44 pages de Annexe B.7 RAE_ISI_IEAQA_AQU MED.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/Annexe B.1 AMI_Pret_Bird.pdf
# Ajouté 2 pages de Annexe B.1 AMI_Pret_Bird.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/Annexe B.3 Mail ISI - 1er Prix World Quality Comitment 2017.pdf
# Ajouté 0 pages de Annexe B.3 Mail ISI - 1er Prix World Quality Comitment 2017.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/Annexe B.4 Récap Plans Processus.pdf
# Ajouté 27 pages de Annexe B.4 Récap Plans Processus.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/Annexe B.6 Plan Processus Gestion Scolarité des Apprenants.pdf
# Ajouté 6 pages de Annexe B.6 Plan Processus Gestion Scolarité des Apprenants.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/Annexe B.14 Résultat -Enquête de satisfaction des enseignants.pdf
# Ajouté 25 pages de Annexe B.14 Résultat -Enquête de satisfaction des enseignants.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/Résultat Enquete de satisfaction étudiants.pdf
# Ajouté 62 pages de Résultat Enquete de satisfaction étudiants.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/Résultat -Enquête de satisfaction du personnel.pdf
# Ajouté 15 pages de Résultat -Enquête de satisfaction du personnel.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/Annexe B.1-2-2.pdf
# Ajouté 1 pages de Annexe B.1-2-2.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/Annexe B.1-2-1.pdf
# Ajouté 1 pages de Annexe B.1-2-1.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/A.14 Charte Usage Resp Numérique.pdf
# Ajouté 2 pages de A.14 Charte Usage Resp Numérique.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/A.12 Liste RH.pdf
# Ajouté 8 pages de A.12 Liste RH.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/A.11 Productions_Scientifiques.pdf
# Ajouté 6 pages de A.11 Productions_Scientifiques.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/A.8 Réglementation en vigueur.pdf
# Ajouté 103 pages de A.8 Réglementation en vigueur.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/A.5 POS_ISI.pdf
# Ajouté 9 pages de A.5 POS_ISI.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/A.4 Politique_ISI.pdf
# Ajouté 0 pages de A.4 Politique_ISI.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/A.3 Statut EPA TN.pdf
# Ajouté 28 pages de A.3 Statut EPA TN.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/A.2 Organisation_enseignement_sup.pdf
# Ajouté 13 pages de A.2 Organisation_enseignement_sup.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/A.1 Statut ISI - Décret de création.pdf
# Ajouté 12 pages de A.1 Statut ISI - Décret de création.pdf.
# Chargement du fichier PDF : /content/drive/MyDrive/Accreditation/RSE.pdf
# Ajouté 2 pages de RSE.pdf.
# Page 1 :
# Dossier d’Accréditation – INGENIEUR
# de l’Institut Supérieur d’Informatique
# Rapport d’auto-évaluation
# Février 2024
# ----------------------------------------
# Page 2 :
# i
#
#
# MOT DU DIRECTEUR
#
# Chères lectrices, chers lecteurs,
# Depuis sa fondation en 2001, l'ISI s'est constamment adapté aux évolutions des besoins des
# formations d'ingénieurs, notamment dans le domaine de l'informatique et de ses applications. Au
# cours de la dernière décennie, nous avons constaté une augmentation significative des demandes
# d'admission émanant d'étudiants souhai tant rejoindre nos programmes. Cette tendance positive
# témoigne de l'intérêt croissant des jeunes talents pour nos cursus.
# Soucieux d'innover et de répondre à une diversité de besoins en formation, l'ISI accorde une
# attention particulière à l'employabilité de ses diplômés et à l'égalité des chances dans l'accès à ses
# formations. Dans cette perspective, nous prévoyons d'intensi fier nos efforts afin d'attirer des
# candidats de qualité et de sélectionner les meilleurs profils.
# Dans une politique de rayonnement, nous nous engageons à renforcer nos partenariats avec des
# acteurs nationaux et internationaux, qu'ils soient du milieu académique ou industriel. Nous incitons
# également notre conseil scientifique à établir des collaborations étroites avec nos partenaires socio-
# économiques.
# Conscients de l'importance du développement pédagogique de notre corps enseignant, nous veillons
# à leur fournir les ressources nécessaires, que ce soit sur le plan matériel, numérique ou financier. Par
# ailleurs, nous nous efforçons d'évaluer et d'améliorer  le niveau de satisfaction des étudiants, des
# enseignants et du personnel dans toutes nos activités pédagogiques, culturelles et
# organisationnelles. Dans cette optique, nous avons lancé une campagne de sensibilisation pour
# promouvoir notre démarche qualité et nous conformer aux normes internationales, notamment en
# mettant en place un système de management pour les organismes d'éducation selon la norme ISO
# 21001.
# Malgré notre envergure, avec près de 1600 étudiants, nous assumons pleinement notre
# responsabilité envers tous nos étudiants et les parties prenantes en :
# - Offrant une formation adaptée aux exigences du marché de l'emploi et aux besoins spécifiques.
# - Respectant les droits de propriété intellectuelle et la vie privée, tout en intégrant nos
# responsabilités sociales et environnementales ainsi que les besoins spécifiques en matière de
# formation.
# - Proposant un cadre propice à une vie étudiante épanouissante sur les plans culturel, sportif et
# associatif.
# ----------------------------------------
# Page 3 :
# ii
#
# Au nom de tous mes collègues et de l'administration, je tiens à exprimer ma profonde gratitude
# envers toutes les personnes qui ont contribué, par leur temps et leurs idées, à rehausser le prestige
# de l'ISI à travers divers projets, que ce soit en matière d 'organisation, par la mise en place d'un
# système SMOE ISO 21001, d'accréditation selon le label CTI -EUR-ACE ou encore par notre
# participation à des projets nationaux et internationaux.
# Nous croyons fermement que notre institution progressera davantage en favorisant une
# gouvernance transparente et inclusive, qui renforce la coopération, la coordination et la
# communication.
#
#
# Votre collègue,
# Salah SALHI
# Directeur de l'ISI
# ----------------------------------------
# Page 4 :
# iii
#
# PRÉAMBULE
#
# Ce dossier est le fruit d’un travail collaboratif sous la responsabilité du directeur de l’ISI, pour une
# auto-évaluation en vue de l’attribution du label européen EUR -ACE pour les diplômes d’ingénieur
# délivrés par notre institution par la Commission des Titres d’Ingénieur (CTI).
#
# Les trois diplômes concernés sont les suivants :
# - Ingénierie de Développement des Logiciels (IDL) ;
# - Ingénierie des Systèmes Embarqués et Objets Connectés (ISEOC) ;
# - Ingénierie et Développement des Infrastructures et des Services de Communications (IDISC).
#
# Il s’agit d es diplômes issus des formations  de trois ans, destinées aux élèves ingénieurs recrutés
# principalement à travers des concours spécifiques nationaux d’entrée aux cycles de formation
# d’ingénieurs.
#
# Cette demande d’évaluation est réalisée dans le cadre de l'évaluation des parcours de l'ISI et appuyée
# par une démarche de management de son système SMOE, conforme à la norme internationale ISO
# 21001.
#
# Le rapport d’auto-évaluation contenu dans ce dossier est conforme au guide d'auto-évaluation de la
# CTI jusqu'à la rentrée 2023-2024.
# ----------------------------------------
# Page 5 :
# iv
#
#
# SOMMAIRE
#
# MOT DU DIRECTEUR ............................................................................................................................... i
# PREAMBULE .......................................................................................................................................... iii
# FICHE SPECIFIANT LE PERIMETRE DE L'AUDIT………………………….………………………………………………………..1
# PRESENTATION GENERALE DE L’INSTITUT ............................................................................................. 3
# A L'INSTITUT ET SA GOUVERNANCE .................................................................................................. 5
# A.1 Identité et autonomie ............................................................................................................. 5
# A.2 Stratégie .................................................................................................................................. 6
# A.2.1 Responsabilité sociétale et environnementale ............................................................... 6
# A.2.2 Politique de site ............................................................................................................... 7
# A.2.3 Communication ................................................................................................................ 7
# A.3 Gouvernance ........................................................................................................................... 8
# A.3.1 Instances d’administration .............................................................................................. 8
# A.3.2 Organisation de l’institut ................................................................................................. 9
# A.4 Missions de l’ISI ....................................................................................................................... 9
# A.4.1 Offre de formation de l’ISI ............................................................................................... 9
# A.4.2 Politique de recherche ................................................................................................... 10
# A.5 Moyens et leur emploi .......................................................................................................... 11
# A.5.1 Ressources humaines ..................................................................................................... 11
# A.5.2 Locaux et ressources matérielles ................................................................................... 12
# A.5.3 Systèmes d’information et moyens numériques ........................................................... 12
# A.5.4 Moyens financiers .......................................................................................................... 13
# B LE MANAGEMENT DE L’INSTITUT : SON PILOTAGE, SON FONCTIONNEMENT ET SON SYSTEME
# QUALITE ............................................................................................................................................... 15
# B.1 Principes de pilotage, gestion .................................................................................................... 15
# B.1 Démarche qualité .................................................................................................................. 15
# B.1.1 Politique de qualité ........................................................................................................ 15
# B.1.2 Amélioration continue ................................................................................................... 17
# B.1.3 Démarche qualité externe hors CTI ............................................................................... 17
# B.1.4 Démarche qualité interne .............................................................................................. 18
# C ANCRAGE ET PARTENARIATS ....................................................................................................... 21
# ----------------------------------------

# %%
import os
from langchain.document_loaders import PyPDFLoader

# Chemin du dossier principal sur Google Drive
root_folder = '/content/drive/MyDrive/Dossier_Accreditation CTI_ISI_2024__'  # Remplacez avec le chemin vers votre dossier principal

# Liste pour stocker le contenu de tous les PDFs
all_pages = []

# Parcourir récursivement tous les sous-dossiers et fichiers dans le dossier
for folder_name, subfolders, filenames in os.walk(root_folder):
    for filename in filenames:
        if filename.lower().endswith('.pdf'):  # Vérifie si le fichier est un PDF
            pdf_path = os.path.join(folder_name, filename)
            print(f"Chargement du fichier PDF : {pdf_path}")

            # Charger le PDF avec PyPDFLoader et diviser en pages
            pdf_loader = PyPDFLoader(pdf_path)
            pages = pdf_loader.load_and_split()

            # Ajouter toutes les pages du PDF à la liste all_pages
            all_pages.extend(pages)

# Afficher un aperçu des pages extraites
for i, page in enumerate(all_pages[:5]):  # Affiche les 5 premières pages pour un aperçu
    print(f"Page {i+1} :\n{page.page_content}\n{'-' * 40}")
# Out:
# Chargement du fichier PDF : /content/drive/MyDrive/Dossier_Accreditation CTI_ISI_2024__/RAE_CTI_ISI_19.02.2024.pdf
# Chargement du fichier PDF : /content/drive/MyDrive/Dossier_Accreditation CTI_ISI_2024__/DN/Chapitre E/Annexe E.4.pdf
# Chargement du fichier PDF : /content/drive/MyDrive/Dossier_Accreditation CTI_ISI_2024__/DN/Chapitre E/Annexe E.5.pdf
# Chargement du fichier PDF : /content/drive/MyDrive/Dossier_Accreditation CTI_ISI_2024__/DN/Chapitre E/Annexe E.1.pdf
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-0c992ba99601> in <cell line: 11>()
#      17             # Charger le PDF avec PyPDFLoader et diviser en pages
#      18             pdf_loader = PyPDFLoader(pdf_path)
# ---> 19             pages = pdf_loader.load_and_split()
#      20
#      21             # Ajouter toutes les pages du PDF à la liste all_pages
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/document_loaders/base.py in load_and_split(self, text_splitter)
#      64         else:
#      65             _text_splitter = text_splitter
# ---> 66         docs = self.load()
#      67         return _text_splitter.split_documents(docs)
#      68
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/document_loaders/base.py in load(self)
#      29     def load(self) -> list[Document]:
#      30         """Load data into Document objects."""
# ---> 31         return list(self.lazy_load())
#      32
#      33     async def aload(self) -> list[Document]:
#
# /usr/local/lib/python3.10/dist-packages/langchain_community/document_loaders/pdf.py in lazy_load(self)
#     255         else:
#     256             blob = Blob.from_path(self.file_path)  # type: ignore[attr-defined]
# --> 257         yield from self.parser.parse(blob)
#     258
#     259
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/document_loaders/base.py in parse(self, blob)
#     125             List of documents
#     126         """
# --> 127         return list(self.lazy_parse(blob))
#
# /usr/local/lib/python3.10/dist-packages/langchain_community/document_loaders/parsers/pdf.py in lazy_parse(self, blob)
#     121
#     122         with blob.as_bytes_io() as pdf_file_obj:  # type: ignore[attr-defined]
# --> 123             pdf_reader = pypdf.PdfReader(pdf_file_obj, password=self.password)
#     124
#     125             yield from [
#
# /usr/local/lib/python3.10/dist-packages/pypdf/_reader.py in __init__(self, stream, strict, password)
#     131         self._validated_root: Optional[DictionaryObject] = None
#     132
# --> 133         self._initialize_stream(stream)
#     134
#     135         self._override_encryption = False
#
# /usr/local/lib/python3.10/dist-packages/pypdf/_reader.py in _initialize_stream(self, stream)
#     153             self._stream_opened = True
#     154         self._startxref: int = 0
# --> 155         self.read(stream)
#     156         self.stream = stream
#     157
#
# /usr/local/lib/python3.10/dist-packages/pypdf/_reader.py in read(self, stream)
#     605
#     606         """
# --> 607         self._basic_validation(stream)
#     608         self._find_eof_marker(stream)
#     609         startxref = self._find_startxref_pos(stream)
#
# /usr/local/lib/python3.10/dist-packages/pypdf/_reader.py in _basic_validation(self, stream)
#     667         stream.seek(0, os.SEEK_SET)
#     668         try:
# --> 669             header_byte = stream.read(5)
#     670         except UnicodeDecodeError:
#     671             raise UnsupportedOperation("cannot read header")
#
# KeyboardInterrupt:

# %% [markdown]
# Extract text from PDF

# %% [markdown]
# # RAG Pipeline: Embedding + Gemini

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %%
import chromadb

chroma_client = chromadb.PersistentClient(path=r"/content/chroma_db")

collection = chroma_client.get_or_create_collection(name="tutorial",metadata={"hnsw:space": "cosine"})

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
import chromadb




# Initialisation de l'outil de découpe de texte
text_splitter = RecursiveCharacterTextSplitter(chunk_size=200, chunk_overlap=100)

# Créer un contexte combiné à partir de toutes les pages
context = "\n\n".join(str(p.page_content) for p in all_pages)
texts = text_splitter.split_text(context)

# Préparer les documents, métadonnées et ids pour ChromaDB
documents = []
metadata = []
ids = []
i = 0
# Parcourir chaque chunk de texte découpé
for i, chunk in enumerate(texts):
    documents.append(chunk)  # Ajouter directement le texte découpé
    ids.append("ID" + str(i))  # Créer un ID unique pour chaque chunk

    # Calculer le numéro de page approximatif, ajuster si nécessaire
    page_number = i // len(texts) * len(all_pages) + 1  # Ajustez ce calcul si nécessaire



    metadata.append({
        "source": "/A.4 Politique_ISI.pdf",  # Utilisation dynamique du nom du fichier
        "chunk_index": i,     # L'ordre du chunk
        "page_number": page_number,  # Numéro approximatif de la page
        "timestamp": "2024-11-11"  # Exemple de timestamp, à adapter si nécessaire
    })

# Assurez-vous que vous avez une collection ChromaDB disponible
chroma_client = chromadb.PersistentClient(path="/content/chroma_db")
collection = chroma_client.get_or_create_collection(name="tutorial")

collection.upsert(
    documents=documents,
    metadatas=metadata,
    ids=ids
)

print("Documents et métadonnées ajoutés avec succès à ChromaDB.")
# Out:
# Documents et métadonnées ajoutés avec succès à ChromaDB.

# %%
for i, chunk in enumerate(texts):
    print(f"Chunk {i + 1} (Length: {len(chunk)}):\n{chunk}\n{'-' * 50}\n")
# Out:
# Streaming output truncated to the last 5000 lines.
# CYBERSECURITY CONFERENCE MEA 2023 » (Annexe C.8).
# Analyse SWOT
# Forces Faiblesse
# --------------------------------------------------
#
# Chunk 768 (Length: 182):
# CYBERSECURITY CONFERENCE MEA 2023 » (Annexe C.8).
# Analyse SWOT
# Forces Faiblesse
# - Renommée et rayonnement nationale et
# internationale.
# - Fort sentiment d’appartenance de la part
# --------------------------------------------------
#
# Chunk 769 (Length: 198):
# internationale.
# - Fort sentiment d’appartenance de la part
# des étudiants et des Alumni.
# - Stratégie efficace pour l'innovation,
# l'entrepreneuriat et l'établissement d'un
# réseau de partenariats.
# --------------------------------------------------
#
# Chunk 770 (Length: 185):
# l'entrepreneuriat et l'établissement d'un
# réseau de partenariats.
# - Manque de R&D.
# - Faible nombre de coopération
# internationale (académique et
# industrielle).
# Opportunités Menaces
# --------------------------------------------------
#
# Chunk 771 (Length: 193):
# internationale (académique et
# industrielle).
# Opportunités Menaces
# - Localisation stratégique pour favoriser les
# partenariats.
# - Forte demande du marché IT.
#
# - Expatriation des étudiants.
# --------------------------------------------------
#
# Chunk 772 (Length: 172):
# 28
#
# D LA FORMATION D’INGÉNIEURS
# D.1 Élaboration du projet de formation
# Le domaine des technologies de l'information et de la communication (TIC) en Tunisie joue un rôle
# --------------------------------------------------
#
# Chunk 773 (Length: 188):
# Le domaine des technologies de l'information et de la communication (TIC) en Tunisie joue un rôle
# essentiel dans la croissance économique du pays grâce à l'évolution rapide des métiers du
# --------------------------------------------------
#
# Chunk 774 (Length: 181):
# essentiel dans la croissance économique du pays grâce à l'évolution rapide des métiers du
# numérique. Des enquêtes nationales et internationales ont été menées pour évaluer le monde
# --------------------------------------------------
#
# Chunk 775 (Length: 194):
# numérique. Des enquêtes nationales et internationales ont été menées pour évaluer le monde
# professionnel des technologies de l'information (IT). Ces études réalisées par des organismes tels que
# --------------------------------------------------
#
# Chunk 776 (Length: 102):
# la Société Financière Internationale (IFC) en partenariat avec la Fédération nationale des TIC (UTICA)
# --------------------------------------------------
#
# Chunk 777 (Length: 97):
# et le cabinet Cooptalis montrent une évolution continue des opportunités d'emploi dans le secteur
# --------------------------------------------------
#
# Chunk 778 (Length: 197):
# d’IT au sein des entreprises tunisiennes et françaises. Une autre étude, réalisée par France Stratégie
# et Dares , a prédit une augmentation de 26 % dans le secteur de l'ingénierie en développement
# --------------------------------------------------
#
# Chunk 779 (Length: 192):
# et Dares , a prédit une augmentation de 26 % dans le secteur de l'ingénierie en développement
# informatique et en nouvelles technologies d'ici 2030, ce qui correspond à 115 000 nouveaux postes
# --------------------------------------------------
#
# Chunk 780 (Length: 188):
# informatique et en nouvelles technologies d'ici 2030, ce qui correspond à 115 000 nouveaux postes
# par rapport à 2019. Conscient des évolutions technologiques et des besoin s du secteur du
# --------------------------------------------------
#
# Chunk 781 (Length: 184):
# par rapport à 2019. Conscient des évolutions technologiques et des besoin s du secteur du
# numérique, l'ISI s'est engagé depuis plusieurs années dans un processus essentiel et délicat,
# --------------------------------------------------
#
# Chunk 782 (Length: 192):
# numérique, l'ISI s'est engagé depuis plusieurs années dans un processus essentiel et délicat,
# nécessitant une compréhension approfondie des exigences du marché national et international ainsi
# --------------------------------------------------
#
# Chunk 783 (Length: 193):
# nécessitant une compréhension approfondie des exigences du marché national et international ainsi
# que des aspirations des étudiants. D’autre part,  la politique mise en œuvre par l'Etat vise à
# --------------------------------------------------
#
# Chunk 784 (Length: 103):
# promouvoir le taux de croissance du secteur des TIC et d’attirer plus d’investisseurs potentiels. Cette
# --------------------------------------------------
#
# Chunk 785 (Length: 193):
# politique se traduit par des actions telles que la délocalisation facile de données, la détaxe des
# équipements informatiques importés, l’encouragement à la création d’emplois qualifiés et à la
# --------------------------------------------------
#
# Chunk 786 (Length: 195):
# équipements informatiques importés, l’encouragement à la création d’emplois qualifiés et à la
# création d’entreprises informatiques. Ceci témoigne de l’importance de ce secteur et représente l'un
# --------------------------------------------------
#
# Chunk 787 (Length: 100):
# des atouts majeurs du projet de formation de l'ISI. Par ailleurs, la  Tunisie attire de plus en plus
# --------------------------------------------------
#
# Chunk 788 (Length: 97):
# d’entreprises européennes et étrangères exerçant principalement dans le domaine de l’informatique
# --------------------------------------------------
#
# Chunk 789 (Length: 190):
# et de l’IT (Annexe D.1). À l'échelle régionale, la majorité de ces entreprises sont localisées dans le
# Grand Tunis (67%), ce qui constitue aussi un atout majeur pour les étudiants de l’ISI.
# --------------------------------------------------
#
# Chunk 790 (Length: 188):
# Grand Tunis (67%), ce qui constitue aussi un atout majeur pour les étudiants de l’ISI.
# Dans cette perspective, l’ISI s'est engagée dans un processus continu d'élaboration et de conception
# --------------------------------------------------
#
# Chunk 791 (Length: 196):
# de programmes visant à offrir à ses futurs ingénieurs une formation agile, capable de s'adapter
# rapidement aux évolutions technologiques tout en étant conscient des défis et des risques inhérents
# --------------------------------------------------
#
# Chunk 792 (Length: 195):
# à un progrès technologique. En se référant sur les études mentionnées précédemment qui ont permis
# d'établir un classement des 20 métiers de l'IT les plus recherchés, l'ISI propose des formations
# --------------------------------------------------
#
# Chunk 793 (Length: 194):
# d'établir un classement des 20 métiers de l'IT les plus recherchés, l'ISI propose des formations
# d'ingénieurs axées s ur les métiers en tête du classement tels qu’Expert DevOps, Data Scientist,
# --------------------------------------------------
#
# Chunk 794 (Length: 196):
# d'ingénieurs axées s ur les métiers en tête du classement tels qu’Expert DevOps, Data Scientist,
# Ingénieur IoT, ainsi que les métiers associés au cloud et à la sécurité informatique des systèmes.
# --------------------------------------------------
#
# Chunk 795 (Length: 197):
# Ingénieur IoT, ainsi que les métiers associés au cloud et à la sécurité informatique des systèmes.
# Outre leurs compétences scientifiques acquises grâce à une formation d’actualité,  les ingénieurs
# --------------------------------------------------
#
# Chunk 796 (Length: 103):
# diplômés de l'ISI, sont dotés de capacités d'innovation, d'ingéniosité, d'esprit critique, une aptitude
# --------------------------------------------------
#
# Chunk 797 (Length: 197):
# à l'auto-formation pour relever les défis scientifiques, technologiques et socio -économique. Ils sont
# également dotés d'une conscience sociale et d'une vision étendue de leur domaine d'expertise.
# --------------------------------------------------
#
# Chunk 798 (Length: 197):
# également dotés d'une conscience sociale et d'une vision étendue de leur domaine d'expertise.
# Afin de garantir un bon déroulement ainsi que le suivi et l'évaluation continue du cursus de formation
# --------------------------------------------------
#
# Chunk 799 (Length: 198):
# d'ingénieurs, en veillant à ce qu'il réponde aux exigences du marché tout en offrant une éducation
# de haut niveau, il est essentiel d'impliquer les parties prenantes, notamment les enseignants, les
# --------------------------------------------------
#
# Chunk 800 (Length: 196):
# étudiants, l'industrie et les expe rts. Ceci se traduit par la mise en place de comités pédagogiques
# (équivalent au conseil de perfectionnement ou CP) au sein de chaque département dans le but de
# --------------------------------------------------
#
# Chunk 801 (Length: 198):
# (équivalent au conseil de perfectionnement ou CP) au sein de chaque département dans le but de
# favoriser le dialogue entre les enseignants d’une même discipline, les étudiants et les représe ntants
# --------------------------------------------------
#
# Chunk 802 (Length: 124):
# du monde professionnel.
# Le comité pédagogique (CP) est composé de :
# - Directeur du département concerné, qui le préside,
# --------------------------------------------------
#
# Chunk 803 (Length: 192):
# du monde professionnel.
# Le comité pédagogique (CP) est composé de :
# - Directeur du département concerné, qui le préside,
# - Enseignants responsables des modules à la charge du département,
# --------------------------------------------------
#
# Chunk 804 (Length: 150):
# - Enseignants responsables des modules à la charge du département,
# - Enseignants intervenants dans la même discipline et participants audits modules,
# --------------------------------------------------
#
# Chunk 805 (Length: 135):
# 29
#
# - Un à deux élèves ingénieurs représentant(s) de la filière en cours de scolarité, invité(s) selon
# le besoin de l’ordre du jour,
# --------------------------------------------------
#
# Chunk 806 (Length: 121):
# le besoin de l’ordre du jour,
# - Deux à trois représentants du milieu professionnel (experts et vacataires intervenants).
# --------------------------------------------------
#
# Chunk 807 (Length: 193):
# - Deux à trois représentants du milieu professionnel (experts et vacataires intervenants).
# Le CP est validé par le conseil scientifique et opérationnel depuis l’année universitaire 2022 -2023
# --------------------------------------------------
#
# Chunk 808 (Length: 195):
# (Annexe D.2). Il se réunit au moins une fois par semestre. Il a pour mission  d’émettre des actions
# correctives pour améliorer la qualité de la formation tenant compte des retours d’enquêtes des
# --------------------------------------------------
#
# Chunk 809 (Length: 195):
# correctives pour améliorer la qualité de la formation tenant compte des retours d’enquêtes des
# industriels afin de mettre à jour le contenu de la formation ainsi que les méthodes d’apprentissage
# --------------------------------------------------
#
# Chunk 810 (Length: 105):
# adoptées.
# Le CP prend également en considération les retours de Conseil des Représentants des Etudiants
# --------------------------------------------------
#
# Chunk 811 (Length: 194):
# Le CP prend également en considération les retours de Conseil des Représentants des Etudiants
# (CRE). Ce dernier réunit les représentants de chaque groupe d’étudiants avec la direction et permet
# --------------------------------------------------
#
# Chunk 812 (Length: 191):
# de remonter leurs réclamations et suggestions efficacement. Le s représentants sont élus par les
# étudiants de leurs groupes respectifs en début de chaque année universitaire.  Ce conseil est
# --------------------------------------------------
#
# Chunk 813 (Length: 195):
# étudiants de leurs groupes respectifs en début de chaque année universitaire.  Ce conseil est
# complété par les délégués officiels des étudiants élus pour les représenter au Conseil Scientifique.
# --------------------------------------------------
#
# Chunk 814 (Length: 125):
# D.2 Compétences visées
# L’ISI propose des formations d’ingénieurs appuyées par une large variété de disciplines scientifiques
# --------------------------------------------------
#
# Chunk 815 (Length: 101):
# et technologiques issues du besoin du marché du travail national et international et qui représentent
# --------------------------------------------------
#
# Chunk 816 (Length: 162):
# une formation en IT. Les formations de l'ISI se déclinent ainsi en trois diplômes d’ingénieurs de
# spécialités distinctes dans les métiers du numérique, à savoir.
# --------------------------------------------------
#
# Chunk 817 (Length: 180):
# spécialités distinctes dans les métiers du numérique, à savoir.
# - Ingénierie de Développement des Logiciels (IDL)
# - Ingénierie des Systèmes Embarqués et Objets Connectés (ISEOC)
# --------------------------------------------------
#
# Chunk 818 (Length: 158):
# - Ingénierie des Systèmes Embarqués et Objets Connectés (ISEOC)
# - Ingénierie et Développement des Infrastructures et des Services de Communications (IDISC).
# --------------------------------------------------
#
# Chunk 819 (Length: 145):
# - Ingénierie et Développement des Infrastructures et des Services de Communications (IDISC).
# D.2.1 Objectifs des formations et compétences visés
# --------------------------------------------------
#
# Chunk 820 (Length: 147):
# D.2.1 Objectifs des formations et compétences visés
# Pour préparer le s élèves -ingénieurs aux métiers, les objectifs des formations d’ingénieur en
# --------------------------------------------------
#
# Chunk 821 (Length: 148):
# Pour préparer le s élèves -ingénieurs aux métiers, les objectifs des formations d’ingénieur en
# numérique proposées dans notre établissement sont :
# --------------------------------------------------
#
# Chunk 822 (Length: 149):
# numérique proposées dans notre établissement sont :
# - Objectif 1. Acquérir une maîtrise approfondie et avancée des concepts théoriques et des outils
# --------------------------------------------------
#
# Chunk 823 (Length: 159):
# - Objectif 1. Acquérir une maîtrise approfondie et avancée des concepts théoriques et des outils
# scientifiques et techniques liés aux sciences de l’ingénieur,
# --------------------------------------------------
#
# Chunk 824 (Length: 156):
# scientifiques et techniques liés aux sciences de l’ingénieur,
# - Objectif 2.  Acquérir des compétences avancées dans la résolution et la  mise en œuvre des
# --------------------------------------------------
#
# Chunk 825 (Length: 164):
# - Objectif 2.  Acquérir des compétences avancées dans la résolution et la  mise en œuvre des
# problèmes complexes liés à chacune des spécialités des métiers ciblés,
# --------------------------------------------------
#
# Chunk 826 (Length: 167):
# problèmes complexes liés à chacune des spécialités des métiers ciblés,
# - Objectif 3. Acquérir des connaissances des enjeux éthiques et sociaux et d’auto-développement
# --------------------------------------------------
#
# Chunk 827 (Length: 127):
# - Objectif 3. Acquérir des connaissances des enjeux éthiques et sociaux et d’auto-développement
# personnel et de communication,
# --------------------------------------------------
#
# Chunk 828 (Length: 179):
# personnel et de communication,
# - Objectif 4.  Avoir la capacité managériale de gérer et d’entreprendre des projets ainsi que la
# culture et l’ouverture industrielle (Softskills).
# --------------------------------------------------
#
# Chunk 829 (Length: 151):
# culture et l’ouverture industrielle (Softskills).
# Pour atteindre ces objectifs, la formation de l’ISI se fait selon l’approche par compétences métiers
# --------------------------------------------------
#
# Chunk 830 (Length: 99):
# identifiées par plusieurs référentiels compétences : le référentiel Métiers/Compétences élaboré par
# --------------------------------------------------
#
# Chunk 831 (Length: 101):
# l’UTICA et la Banque Mondiale en 2017 et réactualisé en 2020 et les référentiels IFC, REM/REC, OPEIIC
# --------------------------------------------------
#
# Chunk 832 (Length: 188):
# et RTMC, développé par l’ Agence Nationale pour l'Emploi et le Travail Indépendant  (ANETI).  Ces
# compétences retenues comportent les compétences génériques préconisées par le référentiel
# --------------------------------------------------
#
# Chunk 833 (Length: 185):
# compétences retenues comportent les compétences génériques préconisées par le référentiel
# d’accréditation pour toute formation d’ingénieur et un ensemble de compétences spécifiques qui
# --------------------------------------------------
#
# Chunk 834 (Length: 147):
# d’accréditation pour toute formation d’ingénieur et un ensemble de compétences spécifiques qui
# énumèrent les compétences attendues de l’ingénieur.
# --------------------------------------------------
#
# Chunk 835 (Length: 155):
# énumèrent les compétences attendues de l’ingénieur.
# Dans son plan d'études, l'ISI cible les compétences répondant aux attentes des métiers de l'ingénieur.
# --------------------------------------------------
#
# Chunk 836 (Length: 99):
# Afin de garantir le maximum d’adéquation entre les profils des ingénieurs diplômés et les exigences
# --------------------------------------------------
#
# Chunk 837 (Length: 109):
# du marché de l’emploi, l’ISI identifie les défaillances, les écarts et les points faibles afin de définir les
# --------------------------------------------------
#
# Chunk 838 (Length: 101):
# mises à jour et les actions correctives.  Cette approche d’amélioration basée sur le besoin du marché
# --------------------------------------------------
#
# Chunk 839 (Length: 104):
# 30
#
# a mobilisé  les experts locaux, les acteurs du secteur industriel, les chercheurs des laboratoires
# --------------------------------------------------
#
# Chunk 840 (Length: 196):
# scientifiques, pour susciter la réactivité de l’ISI face aux évolutions technologiques du marché de
# l’emploi.  Cette démarche est amenée à être reconduite périodiquement chaque année pour l’auto-
# --------------------------------------------------
#
# Chunk 841 (Length: 159):
# l’emploi.  Cette démarche est amenée à être reconduite périodiquement chaque année pour l’auto-
# évaluation du plan d’études de l’ISI [Détails dans Chapitre G].
# --------------------------------------------------
#
# Chunk 842 (Length: 108):
# évaluation du plan d’études de l’ISI [Détails dans Chapitre G].
# - Les métiers visés par les trois filières
# --------------------------------------------------
#
# Chunk 843 (Length: 142):
# - Les métiers visés par les trois filières
# Les métiers visés par le parcours IDL sont les métiers pour lesquels la demande est en très forte
# --------------------------------------------------
#
# Chunk 844 (Length: 198):
# Les métiers visés par le parcours IDL sont les métiers pour lesquels la demande est en très forte
# augmentation selon un classement établi à partir d’une enquête en ligne Katalyse/erdyn. Les métiers
# --------------------------------------------------
#
# Chunk 845 (Length: 196):
# liés aux nouvelles technologies telsqu’Expert DevOps, Data Scientist ont marqué la dernière
# décennie. Les métiers d’actualité visés par le parcours ISEOC, sont les métiers Ingénieur et Architecte
# --------------------------------------------------
#
# Chunk 846 (Length: 99):
# en embarqué et IoT. Selon l’Institut Forrester  prédit que l’IoT passe de l’échelle expérimentale à
# --------------------------------------------------
#
# Chunk 847 (Length: 103):
# l’échelle commerciale et que les plateformes IoT spécialisées vont se développer pour faciliter l’accès
# --------------------------------------------------
#
# Chunk 848 (Length: 97):
# aux solutions connectées. En effet, le nombre de projets d’objets connectés a augmenté de 500% en
# --------------------------------------------------
#
# Chunk 849 (Length: 100):
# trois ans dans le monde, et les entreprises françaises y ont investi plus de 30 milliards d’euros en
# --------------------------------------------------
#
# Chunk 850 (Length: 103):
# 2017.  Les métiers visés par le parcours IDISC sont des métiers en constante évolution selon le cabinet
# --------------------------------------------------
#
# Chunk 851 (Length: 104):
# Robert Half. Les priorités stratégiques des entreprises sont focalisées sur les projets liés au cloud, à
# --------------------------------------------------
#
# Chunk 852 (Length: 96):
# la sécurité informatique des systèmes.  En effet, entre 2016 et 2019, le marché mondial du cloud
# --------------------------------------------------
#
# Chunk 853 (Length: 197):
# public a atteint 233 milliards de dollars de chiffre d’affaires (International Data Corporation). Avec
# 17% de croissance, le cloud continue son expansion mais pour utiliser cette véritable matière
# --------------------------------------------------
#
# Chunk 854 (Length: 197):
# 17% de croissance, le cloud continue son expansion mais pour utiliser cette véritable matière
# première du digital, il faut des candidats de plus en plus experts sur ces technologies. Selon la même
# --------------------------------------------------
#
# Chunk 855 (Length: 197):
# étude du cabinet Robert Half, l’expert en cybersécurité est considéré comme le poste d’avenir  en
# pleine ascension, un pourcentage de 5% bénéficie ainsi du contexte post-Covid et se confirme comme
# --------------------------------------------------
#
# Chunk 856 (Length: 162):
# pleine ascension, un pourcentage de 5% bénéficie ainsi du contexte post-Covid et se confirme comme
# le profil dont la demande va croissante jusqu’en 2025 minimum.
# --------------------------------------------------
#
# Chunk 857 (Length: 160):
# le profil dont la demande va croissante jusqu’en 2025 minimum.
# En effet, Les trois disciplines de l'ingénierie ont pour vocation de développer des compétences
# --------------------------------------------------
#
# Chunk 858 (Length: 105):
# métiers de plusieurs secteurs professionnels répondant à un besoin identifié et significatif relatif à la
# --------------------------------------------------
#
# Chunk 859 (Length: 191):
# conception des systèmes logiciels, des systèmes embarq ués, des réseaux télécommunications, de
# nouvelles technologies, des systèmes intelligents et communicants, etc.  Ces secteurs d'avenir,
# --------------------------------------------------
#
# Chunk 860 (Length: 197):
# nouvelles technologies, des systèmes intelligents et communicants, etc.  Ces secteurs d'avenir,
# porteurs d'innovations technologiques, offrent à nos diplômés d'excellentes opportunités d'insertion
# --------------------------------------------------
#
# Chunk 861 (Length: 143):
# professionnelle et des perspectives à carrières riches et variées répondant aux critères de la CTI en
# mobilisant une approche par compétences.
# --------------------------------------------------
#
# Chunk 862 (Length: 195):
# mobilisant une approche par compétences.
# Un récapitulatif des métiers visés par les trois formations proposées est illustré dans le Tableau D-1.
#
# Tableau D-1 : Métiers visés par les formations
# --------------------------------------------------
#
# Chunk 863 (Length: 159):
# Tableau D-1 : Métiers visés par les formations
# Filière Métiers visés selon les référentiels Métiers/compétences
# Ingénierie de Développement du
# Logiciel, IDL
# --------------------------------------------------
#
# Chunk 864 (Length: 192):
# Ingénierie de Développement du
# Logiciel, IDL
# Concepteur, Développeur, Expert DEVOPS, UI/UX Designer,
# Data Scientist (Analyste de données), Ingénieur IA
# Ingénierie des Systèmes Embarqués et
# --------------------------------------------------
#
# Chunk 865 (Length: 172):
# Data Scientist (Analyste de données), Ingénieur IA
# Ingénierie des Systèmes Embarqués et
# Objets Connectés, ISEOC
#
# Ingénieur des systèmes embarqués, Architecte, Ingénieur
# --------------------------------------------------
#
# Chunk 866 (Length: 197):
# Objets Connectés, ISEOC
#
# Ingénieur des systèmes embarqués, Architecte, Ingénieur
# IoT, Programmeur industriel, Analyste -programmeur en
# Informatique industrielle
# Ingénierie et Développement des
# --------------------------------------------------
#
# Chunk 867 (Length: 177):
# Informatique industrielle
# Ingénierie et Développement des
# Infrastructures et des Services de
# Communications, IDISC
# Responsable de services TIC, Expert sécurité informatique,
# --------------------------------------------------
#
# Chunk 868 (Length: 148):
# Communications, IDISC
# Responsable de services TIC, Expert sécurité informatique,
# Administrateur système, Expert en Virtualisation, Expert
# Réseaux
# --------------------------------------------------
#
# Chunk 869 (Length: 170):
# 31
#
# D.2.2 Cohérence du cursus de formation et des compétences spécifiques
# Pour chaque filière dispensée à l’ISI, les compétences spécifiques sont définies à partir des
# --------------------------------------------------
#
# Chunk 870 (Length: 193):
# Pour chaque filière dispensée à l’ISI, les compétences spécifiques sont définies à partir des
# compétences métiers définies dans les référentiels traduisant les métiers exercés sur le marché de
# --------------------------------------------------
#
# Chunk 871 (Length: 189):
# l’emploi national et international  (REM/REC pour les trois filières  ; OPEIIC pour la filière ISEOC ). Le
# Tableau D-2 illustre les compétences spécifiques des trois filières (Annexe D.3).
# --------------------------------------------------
#
# Chunk 872 (Length: 169):
# Tableau D-2 illustre les compétences spécifiques des trois filières (Annexe D.3).
#
# Tableau D-2 : Compétences spécifiques des trois filières.
#  Compétences Spécifiques
# --------------------------------------------------
#
# Chunk 873 (Length: 156):
# Tableau D-2 : Compétences spécifiques des trois filières.
#  Compétences Spécifiques
# CS1 Maîtriser des outils scientifiques de sciences de l’ingénieur.
# CS2
# --------------------------------------------------
#
# Chunk 874 (Length: 166):
# Compétences Spécifiques
# CS1 Maîtriser des outils scientifiques de sciences de l’ingénieur.
# CS2
# Concevoir, développer et mettre en œuvre des logiciels informatiques
# --------------------------------------------------
#
# Chunk 875 (Length: 156):
# CS2
# Concevoir, développer et mettre en œuvre des logiciels informatiques
# Modéliser et concevoir des applications en systèmes embarqués et objets connectés
# --------------------------------------------------
#
# Chunk 876 (Length: 197):
# Modéliser et concevoir des applications en systèmes embarqués et objets connectés
# Piloter des projets innovants destinés aux systèmes communicants suivant l’évolution des
# technologies émergentes
# --------------------------------------------------
#
# Chunk 877 (Length: 185):
# technologies émergentes
# CS3
# Intégrer et mettre en œuvre des architectures logicielles
# Maîtriser et développer des applications informatiques en rapport avec les systèmes embarqués et
# --------------------------------------------------
#
# Chunk 878 (Length: 129):
# Maîtriser et développer des applications informatiques en rapport avec les systèmes embarqués et
# les systèmes communicants (IoT)
# --------------------------------------------------
#
# Chunk 879 (Length: 177):
# les systèmes communicants (IoT)
# Assurer le fonctionnement technique du système informatique selon les normes liées à la qualité et
# à la sécurité du système d’information.
# CS4
# --------------------------------------------------
#
# Chunk 880 (Length: 108):
# à la sécurité du système d’information.
# CS4
# Concevoir et développer des solutions informatiques innovantes
# --------------------------------------------------
#
# Chunk 881 (Length: 198):
# CS4
# Concevoir et développer des solutions informatiques innovantes
# Maîtriser les concepts du réseau et les protocoles de communication nécessaires pour la création
# d’un objet connecté intelligent
# --------------------------------------------------
#
# Chunk 882 (Length: 178):
# d’un objet connecté intelligent
# Concevoir, développer, mettre en service des solutions TIC et des politiques de sécurité du SI
# CS5
# Planifier et gérer des projets Informatiques
# --------------------------------------------------
#
# Chunk 883 (Length: 153):
# CS5
# Planifier et gérer des projets Informatiques
# Concevoir et mettre en œuvre des applications automatisées dans une chaîne de production
# industrielle
# --------------------------------------------------
#
# Chunk 884 (Length: 184):
# industrielle
# Tester et valider le fonctionnement des SI en termes de connectivité, capacité de l’infrastructure et
# de la sécurité.
# CS6
# Maîtriser des environnements de Programmation
# --------------------------------------------------
#
# Chunk 885 (Length: 126):
# de la sécurité.
# CS6
# Maîtriser des environnements de Programmation
# Instrumenter, tester et valider des dispositifs embarqués
# --------------------------------------------------
#
# Chunk 886 (Length: 156):
# Instrumenter, tester et valider des dispositifs embarqués
# Maîtriser les outils scientifiques de mise en place de nouvelles solutions de stockage virtuel de
# --------------------------------------------------
#
# Chunk 887 (Length: 158):
# Maîtriser les outils scientifiques de mise en place de nouvelles solutions de stockage virtuel de
# données et valider les aspects techniques du stockage.
# CS7
# --------------------------------------------------
#
# Chunk 888 (Length: 110):
# données et valider les aspects techniques du stockage.
# CS7
# Concevoir et développer des systèmes intelligents
# --------------------------------------------------
#
# Chunk 889 (Length: 169):
# CS7
# Concevoir et développer des systèmes intelligents
# Maîtriser la programmation matérielle et logicielle et la co-conception des architectures hétérogènes
# embarquées
# --------------------------------------------------
#
# Chunk 890 (Length: 165):
# embarquées
# Maîtriser les normes et les bonnes pratiques en vue d’auditer les SI et de proposer des améliorations.
# CS8
# Tester et valider des systèmes Informatiques
# --------------------------------------------------
#
# Chunk 891 (Length: 112):
# CS8
# Tester et valider des systèmes Informatiques
# Maîtriser et concevoir des systèmes intelligents et innovants
# --------------------------------------------------
#
# Chunk 892 (Length: 184):
# 32
#
# CS9 Maîtriser les compétences managériales et de culture industrielle (Softskills)
# CS10 Maîtriser les techniques de communication avec un public varié et les langues étrangères.
# --------------------------------------------------
#
# Chunk 893 (Length: 185):
# CS10 Maîtriser les techniques de communication avec un public varié et les langues étrangères.
# CS11 Avoir la capacité de l’auto-développement personnel et professionnel
#
# Filière IDL
# --------------------------------------------------
#
# Chunk 894 (Length: 178):
# CS11 Avoir la capacité de l’auto-développement personnel et professionnel
#
# Filière IDL
# Filière ISEOC
# Filière IDISC
# Compétences spécifiques communes entre les trois filières
# --------------------------------------------------
#
# Chunk 895 (Length: 134):
# Filière ISEOC
# Filière IDISC
# Compétences spécifiques communes entre les trois filières
# D.3 Diplôme d’ingénieur en formation initiale
# --------------------------------------------------
#
# Chunk 896 (Length: 137):
# D.3 Diplôme d’ingénieur en formation initiale
# Depuis la création du cycle ingénieur à l’ISI, l’orienta tion stratégique, comme mentionné
# --------------------------------------------------
#
# Chunk 897 (Length: 187):
# Depuis la création du cycle ingénieur à l’ISI, l’orienta tion stratégique, comme mentionné
# précédemment dans le chapitre A, est de proposer une formation d’ingénieurs de haut niveau dans
# --------------------------------------------------
#
# Chunk 898 (Length: 193):
# précédemment dans le chapitre A, est de proposer une formation d’ingénieurs de haut niveau dans
# les diverses activités reliées au domaine des métiers du numérique. Ainsi, la durée de formation
# --------------------------------------------------
#
# Chunk 899 (Length: 104):
# d’ingénieurs s'étale sur trois années universitaires réparties six semestres au total. Les cinq premiers
# --------------------------------------------------
#
# Chunk 900 (Length: 193):
# semestres d’études concernent principalement la partie académique d’enseignem ent. Les stages
# (Semestres S2 et S4) ainsi que le projet de fin d'études (Semestre S6) se déroulent dans le milieu
# --------------------------------------------------
#
# Chunk 901 (Length: 168):
# (Semestres S2 et S4) ainsi que le projet de fin d'études (Semestre S6) se déroulent dans le milieu
# industriel constituent la partie professionnelle de l’apprentissage.
# --------------------------------------------------
#
# Chunk 902 (Length: 157):
# industriel constituent la partie professionnelle de l’apprentissage.
# Les enseignements sont organisés en unités d’enseignement (UE) regroupant des éléments
# --------------------------------------------------
#
# Chunk 903 (Length: 186):
# Les enseignements sont organisés en unités d’enseignement (UE) regroupant des éléments
# constitutifs (ECUE) qui sont dispensés sous forme de cours (C), de travaux dirigés (TD) et travaux
# --------------------------------------------------
#
# Chunk 904 (Length: 195):
# pratiques (TP) et de travaux personnels (TPE). Ces modules sont dispensés par une durée de 1h30. La
# forme des enseignements des ECUEs, leurs volumes horaires, leurs coefficients, les crédits des
# --------------------------------------------------
#
# Chunk 905 (Length: 191):
# forme des enseignements des ECUEs, leurs volumes horaires, leurs coefficients, les crédits des
# épreuves s’y rapportant, ainsi que les modes d’évaluation sont définis dans le plan d’études de
# --------------------------------------------------
#
# Chunk 906 (Length: 182):
# épreuves s’y rapportant, ainsi que les modes d’évaluation sont définis dans le plan d’études de
# chaque filière qui sont communiqués aux parties intéressées sur le Site web de l’ISI.
# --------------------------------------------------
#
# Chunk 907 (Length: 180):
# chaque filière qui sont communiqués aux parties intéressées sur le Site web de l’ISI.
# - Les ECUEs répondent aux compétences génériques et spécifiques ciblées par la formation, les
# --------------------------------------------------
#
# Chunk 908 (Length: 181):
# - Les ECUEs répondent aux compétences génériques et spécifiques ciblées par la formation, les
# volumes horaires en présentiel et en autonomie (travaux personnels) et les différentes
# --------------------------------------------------
#
# Chunk 909 (Length: 181):
# volumes horaires en présentiel et en autonomie (travaux personnels) et les différentes
# méthodes pédagogiques (C, TD, TP et TPE) sont illustrés dans les plans d’études (Annexe D.3).
# --------------------------------------------------
#
# Chunk 910 (Length: 183):
# méthodes pédagogiques (C, TD, TP et TPE) sont illustrés dans les plans d’études (Annexe D.3).
# - Le tronc commun s’étale sur trois semestres communs (S1 -S3) garantissant un acquis de
# --------------------------------------------------
#
# Chunk 911 (Length: 181):
# - Le tronc commun s’étale sur trois semestres communs (S1 -S3) garantissant un acquis de
# compétences commun à tous les élèves -ingénieurs de la filière, leurs permettant d’intégrer
# --------------------------------------------------
#
# Chunk 912 (Length: 189):
# compétences commun à tous les élèves -ingénieurs de la filière, leurs permettant d’intégrer
# tous les métiers de l’ingénieur tels que les nouvelles technologies, le multimé dia, les réseaux
# --------------------------------------------------
#
# Chunk 913 (Length: 196):
# tous les métiers de l’ingénieur tels que les nouvelles technologies, le multimé dia, les réseaux
# et sécurité ainsi que le pilotage des services et des projets. Les trois autres semestres (S4 -S6)
# --------------------------------------------------
#
# Chunk 914 (Length: 182):
# et sécurité ainsi que le pilotage des services et des projets. Les trois autres semestres (S4 -S6)
# assurent une formation dans l’une des spécialités suivantes : IDL, ISEOC ou IDISC.
# --------------------------------------------------
#
# Chunk 915 (Length: 181):
# assurent une formation dans l’une des spécialités suivantes : IDL, ISEOC ou IDISC.
# - Le nombre d'élèves ingénieurs par classe, ne dépasse pas les 35 élèves pour les cours et les 17
# --------------------------------------------------
#
# Chunk 916 (Length: 160):
# - Le nombre d'élèves ingénieurs par classe, ne dépasse pas les 35 élèves pour les cours et les 17
# élèves pour les TPs réalisés aux laboratoires d’enseignement.
# --------------------------------------------------
#
# Chunk 917 (Length: 178):
# élèves pour les TPs réalisés aux laboratoires d’enseignement.
# - Les semestres d’enseignement ont une durée effective de 15 semaines dont une semaine
# d’évaluation (Annexe D.4).
# --------------------------------------------------
#
# Chunk 918 (Length: 166):
# d’évaluation (Annexe D.4).
# D.3.1 Architecture et programme de formation
# Le détail des déclinaisons de programme de formation par rapport aux compétences visées sont
# --------------------------------------------------
#
# Chunk 919 (Length: 177):
# Le détail des déclinaisons de programme de formation par rapport aux compétences visées sont
# décrites dans les matrices ECUE/Compétences, où chaque ECUE répond à un ensemble de
# --------------------------------------------------
#
# Chunk 920 (Length: 183):
# décrites dans les matrices ECUE/Compétences, où chaque ECUE répond à un ensemble de
# compétences. La description des compétences spécifiques relatives aux trois fil ières (Annexe D.5)
# --------------------------------------------------
#
# Chunk 921 (Length: 195):
# ainsi que la répartition des matières en Tronc Commun (TC) et en spécialité (comprenant les Travaux
# Personnels et le Temps d’Assimilation) complètent la description du programme de la formation.
# --------------------------------------------------
#
# Chunk 922 (Length: 192):
# 33
#
#
# Répartition du volume horaire/compétence et crédits/compétence pour les trois filières
#
#    Figure D-1 : % volume horaire /compétence -IDL-   Figure D-2 : % crédits/compétence -IDL-
# --------------------------------------------------
#
# Chunk 923 (Length: 192):
# Figure D-1 : % volume horaire /compétence -IDL-   Figure D-2 : % crédits/compétence -IDL-
# Figure D -1 illustre que  les trois compétences
# spécifiques les plus significatives du parcours  IDL
# --------------------------------------------------
#
# Chunk 924 (Length: 179):
# spécifiques les plus significatives du parcours  IDL
# sont CS2, CS6 et CS7.
# Figure D-2 représente le pourcentage des crédits par
# compétences spécifiques et montre clairement que
# --------------------------------------------------
#
# Chunk 925 (Length: 121):
# compétences spécifiques et montre clairement que
# les crédits attribués aux CS2, CS6 et CS7 sont les plus
# prépondérants.
# --------------------------------------------------
#
# Chunk 926 (Length: 186):
# les crédits attribués aux CS2, CS6 et CS7 sont les plus
# prépondérants.
#
#
# Figure D-3 : % volume horaire /compétence -ISEOC-                  Figure D-4 : % crédits/compétence -ISEOC-
# --------------------------------------------------
#
# Chunk 927 (Length: 172):
# Figure D-3 illustre les trois compétences spécifiques les
# plus significatives du parcours ISEOC sont CS2, CS3 et
# CS7 qui justifient la teinte de cette formation illustrée
# --------------------------------------------------
#
# Chunk 928 (Length: 153):
# CS7 qui justifient la teinte de cette formation illustrée
# par les systèmes embarqués et/ou communicants.
# Figure D-4 illustre le taux de contribution de
# --------------------------------------------------
#
# Chunk 929 (Length: 185):
# par les systèmes embarqués et/ou communicants.
# Figure D-4 illustre le taux de contribution de
# crédits pa r compétences spécifiques . Il s'avère
# que les taux de crédits correspondants
# --------------------------------------------------
#
# Chunk 930 (Length: 160):
# crédits pa r compétences spécifiques . Il s'avère
# que les taux de crédits correspondants
# respectivement aux CS1, CS2, CS3 et CS7 sont les
# plus prépondérants.
# --------------------------------------------------
#
# Chunk 931 (Length: 160):
# 34
#
#
# Figure D-5 : % volume horaire /compétence -IDISC-                 Figure D-6: % crédits/compétence -IDISC
# Figure D -5 représente les trois compétences
# --------------------------------------------------
#
# Chunk 932 (Length: 147):
# Figure D -5 représente les trois compétences
# spécifiques CS3, CS4 et CS5 sont les trois
# compétences qui justifient la teinte de cette
# formation.
# --------------------------------------------------
#
# Chunk 933 (Length: 164):
# compétences qui justifient la teinte de cette
# formation.
# Figure D-6 représente le pourcentage des crédits par
# compétences spécifiques, montre clairement que  les
# --------------------------------------------------
#
# Chunk 934 (Length: 172):
# compétences spécifiques, montre clairement que  les
# crédits attribués aux CS3, CS4 et CS5 sont les plus
# prépondérants.
# - Répartition de la charge totale sans et avec PFE
# --------------------------------------------------
#
# Chunk 935 (Length: 184):
# prépondérants.
# - Répartition de la charge totale sans et avec PFE
#
#
# Figure D-7 : Répartition de la charge avec PFE -IDL-       Figure D-8 : Répartition de la charge sans PFE -IDL-
# --------------------------------------------------
#
# Chunk 936 (Length: 176):
# La Figure D-7 représente la répartition de la charge
# totale avec PFE en termes de C, TD, TP et T PE pour
# la filière IDL.
# La Figure D-8 représente la répartition de la charge
# --------------------------------------------------
#
# Chunk 937 (Length: 138):
# la filière IDL.
# La Figure D-8 représente la répartition de la charge
# totale sans PFE en termes de C, TD, TP et TPE pour la
# filière IDL.
# --------------------------------------------------
#
# Chunk 938 (Length: 173):
# 35
#
#
# Figure D-9 : Répartition de la charge avec PFE -ISEOC- Figure D-10 : Répartition de la charge sans PFE -ISEOC-
# La Figure D-9 représente la répartition de la charge
# --------------------------------------------------
#
# Chunk 939 (Length: 174):
# La Figure D-9 représente la répartition de la charge
# totale avec PFE en termes de C, TD, TP et TPE pour la
# filière ISEOC.
# La Figure D-10 montre la répartition de la charge
# --------------------------------------------------
#
# Chunk 940 (Length: 136):
# filière ISEOC.
# La Figure D-10 montre la répartition de la charge
# totale sans PFE en termes de C, TD, TP et TPE pour la
# filière ISEOC.
# --------------------------------------------------
#
# Chunk 941 (Length: 186):
# totale sans PFE en termes de C, TD, TP et TPE pour la
# filière ISEOC.
#
# Figure D-11: Répartition de la charge avec PFE -IDISC-   Figure D-12 : Répartition de la charge sans PFE -IDISC-
# --------------------------------------------------
#
# Chunk 942 (Length: 175):
# La Figure D-11 récapitule la répartition de la charge
# totale avec PFE en termes de C, TD, TP et TPE pour la
# filière IDISC.
# La Figure D-12 montre la répartition de la charge
# --------------------------------------------------
#
# Chunk 943 (Length: 136):
# filière IDISC.
# La Figure D-12 montre la répartition de la charge
# totale sans PFE en termes de C, TD, TP et TPE pour la
# filière IDISC.
# --------------------------------------------------
#
# Chunk 944 (Length: 163):
# totale sans PFE en termes de C, TD, TP et TPE pour la
# filière IDISC.
# Ces illustrations mettent en évidence l’importance du PFE qui favorise notamment le taux des
# --------------------------------------------------
#
# Chunk 945 (Length: 184):
# Ces illustrations mettent en évidence l’importance du PFE qui favorise notamment le taux des
# travaux personnels soulignant ainsi l’importance de l’innovation, l’auto -développement et
# --------------------------------------------------
#
# Chunk 946 (Length: 141):
# travaux personnels soulignant ainsi l’importance de l’innovation, l’auto -développement et
# l'entrepreneuriat dans les formations ingénieurs.
# --------------------------------------------------
#
# Chunk 947 (Length: 159):
# 36
#
# Répartition de la Charge horaire selon les familles des CS
#
#
# Figure D-13 : Répartition de la charge globale par familles de CS pour les trois filières
# --------------------------------------------------
#
# Chunk 948 (Length: 193):
# Figure D-13 : Répartition de la charge globale par familles de CS pour les trois filières
# Sur la Figure D-13, qui illustre la répartition du volume horaire par famille de compétences  pour les
# --------------------------------------------------
#
# Chunk 949 (Length: 106):
# trois filières, il est clair que la première famille de compétences « outils scientifiques et techniques »
# --------------------------------------------------
#
# Chunk 950 (Length: 136):
# permet à l’élève ingénieur de maîtriser les outils scientifiques nécessaires pour pouvoir résoudre et
# traiter les problèmes rencontrés.
# --------------------------------------------------
#
# Chunk 951 (Length: 130):
# traiter les problèmes rencontrés.
# On peut observer que la deuxième famille de compétences « compétences technologiques et veille
# --------------------------------------------------
#
# Chunk 952 (Length: 196):
# On peut observer que la deuxième famille de compétences « compétences technologiques et veille
# scientifique » propre à chaque filière, joue un rôle prépondérant dans les trois filières. Il s'agit
# --------------------------------------------------
#
# Chunk 953 (Length: 182):
# d'acquérir des compétences avancées en résolution et à la mise en œuvre de problèmes complexes
# liés à chacune des spécialités des métiers ciblés. La troisième famille de compétences
# --------------------------------------------------
#
# Chunk 954 (Length: 175):
# liés à chacune des spécialités des métiers ciblés. La troisième famille de compétences
# « communication, management, développement personnel et innovation  » permet aux futurs
# --------------------------------------------------
#
# Chunk 955 (Length: 183):
# « communication, management, développement personnel et innovation  » permet aux futurs
# ingénieurs de maîtriser des compétences managér iales, de culture d’entreprises et des langues
# --------------------------------------------------
#
# Chunk 956 (Length: 185):
# ingénieurs de maîtriser des compétences managér iales, de culture d’entreprises et des langues
# étrangères. L’élève ingénieur, au -delà de ces compétences scientifiques, aura le pouvoir
# --------------------------------------------------
#
# Chunk 957 (Length: 191):
# étrangères. L’élève ingénieur, au -delà de ces compétences scientifiques, aura le pouvoir
# d'entreprendre, d’innover et de s'auto -développer sur les plans personnel et relationnel, à travers
# --------------------------------------------------
#
# Chunk 958 (Length: 100):
# des travaux personnels, des mini-projets, des stages d’initiation et de perfectionnement et des PFE.
# --------------------------------------------------
#
# Chunk 959 (Length: 148):
# Ces compétences appréhendent le travail en équipe, et la communication dans le cadre professionnel
# et public.
# Evaluation des compétences acquises
# --------------------------------------------------
#
# Chunk 960 (Length: 144):
# et public.
# Evaluation des compétences acquises
# Afin de s’assurer des compétences acquises par nos élèves ingénieurs à l’ISI à la fin de leurs
# --------------------------------------------------
#
# Chunk 961 (Length: 190):
# Afin de s’assurer des compétences acquises par nos élèves ingénieurs à l’ISI à la fin de leurs
# formations, l’évaluation de ces dernières est réalisée selon les moyennes obtenues dans chaque
# --------------------------------------------------
#
# Chunk 962 (Length: 176):
# formations, l’évaluation de ces dernières est réalisée selon les moyennes obtenues dans chaque
# ECUE alimentant la compétence concernée selon la méthodologie/formule suivante :
# --------------------------------------------------
#
# Chunk 963 (Length: 180):
# ECUE alimentant la compétence concernée selon la méthodologie/formule suivante :
#
# ηj  =   ∑i(ci* xi,CSJ)
# ∑ici
# Avec, Xi, CSJ : le % pourcentage ayant plus que la moyenne 10/20
# --------------------------------------------------
#
# Chunk 964 (Length: 131):
# ηj  =   ∑i(ci* xi,CSJ)
# ∑ici
# Avec, Xi, CSJ : le % pourcentage ayant plus que la moyenne 10/20
# dans l'ECUE i de la compétence j ;
# --------------------------------------------------
#
# Chunk 965 (Length: 145):
# dans l'ECUE i de la compétence j ;
# Ci : niveau d'acquis d'apprentissage du ECUE i (Ci allant de 1 à 3)
# Figure D-14 : Evaluation des Compétences
# --------------------------------------------------
#
# Chunk 966 (Length: 108):
# 37
#
# ...
# doit faire face à des défis majeurs, notamment une concurrence croissante avec les é coles privées,
# des pressions financières et une bureaucratie pesante. De plus, la fuite de compétences vers
# --------------------------------------------------
#
# Chunk 1568 (Length: 187):
# des pressions financières et une bureaucratie pesante. De plus, la fuite de compétences vers
# l'étranger ajoute à la complexité de son environnement. Pourtant, son emplacement stratégique
# --------------------------------------------------
#
# Chunk 1569 (Length: 195):
# l'étranger ajoute à la complexité de son environnement. Pourtant, son emplacement stratégique
# favorise les partenariats et renforce son identité ins titutionnelle, soutenue par un fort sentiment
# --------------------------------------------------
#
# Chunk 1570 (Length: 197):
# d'appartenance des étudiants et des anciens élèves. En somme, l'ISI navigue avec agilité dans un
# paysage en constante évolution, capitalisant sur ses forces tout en relevant avec détermination les
# --------------------------------------------------
#
# Chunk 1571 (Length: 150):
# défis inhérents à son développement futur.
#
# L'Institut Supérieur d'Informatique sollicite l'accréditation de ses parcours ingénieurs, présentant des
# --------------------------------------------------
#
# Chunk 1572 (Length: 99):
# projets ambitieux et porteurs pour ses diplômes. Cette démarche intervient dans un contexte crucial
# --------------------------------------------------
#
# Chunk 1573 (Length: 190):
# où l'industrie de l'informatique exige plus que jam ais la formation de cadres dotés de créativité,
# d'innovation, et d'une adaptation sans faille aux progrès technologiques et scientifiques
# --------------------------------------------------
#
# Chunk 1574 (Length: 155):
# d'innovation, et d'une adaptation sans faille aux progrès technologiques et scientifiques
# contemporains, ainsi qu'aux mutations accélérées de notre monde.
# --------------------------------------------------
#
# Chunk 1575 (Length: 137):
# 1
# Critères de Sélection des Candidats aux Concours Spécifiques d’accès
# aux Etablissements de Formation d’Ingénieurs
#
# (Première année)
# --------------------------------------------------
#
# Chunk 1576 (Length: 160):
# aux Etablissements de Formation d’Ingénieurs
#
# (Première année)
#
# 1. Un score global sera attribué à chaque candidat des concours spécifiques. Il correspond à
# --------------------------------------------------
#
# Chunk 1577 (Length: 154):
# 1. Un score global sera attribué à chaque candidat des concours spécifiques. Il correspond à
# la combinaison linéaire de deux scores : score A et score E.
# --------------------------------------------------
#
# Chunk 1578 (Length: 162):
# la combinaison linéaire de deux scores : score A et score E.
#
# Score global = Score A*0.7 + Score E*0.3
#
# Le score global est calculé sur la base de 100 points.
# --------------------------------------------------
#
# Chunk 1579 (Length: 149):
# Score global = Score A*0.7 + Score E*0.3
#
# Le score global est calculé sur la base de 100 points.
# Le score A est calculé sur la base de 100 points.
# --------------------------------------------------
#
# Chunk 1580 (Length: 198):
# Le score A est calculé sur la base de 100 points.
# Le score E est calculé sur la base de 100 points.
#
# a) Score A : Ce score tient compte des critères communs à tous les établissements de formation
# --------------------------------------------------
#
# Chunk 1581 (Length: 190):
# a) Score A : Ce score tient compte des critères communs à tous les établissements de formation
# d’ingénieurs concernés par les concours spécifiques et il est calculé de la manière suivante :
# --------------------------------------------------
#
# Chunk 1582 (Length: 157):
# d’ingénieurs concernés par les concours spécifiques et il est calculé de la manière suivante :
#
# Score A = 0.2* M + 1.4/3* R +5/6*ML+ 2/3*( B1 + B2)
# Où   :
# --------------------------------------------------
#
# Chunk 1583 (Length: 192):
# Score A = 0.2* M + 1.4/3* R +5/6*ML+ 2/3*( B1 + B2)
# Où   :
#
# − M est fonction de Mg qui est la moyenne générale durant les deux premières années de la
# formation de la licence (système LMD).
# --------------------------------------------------
#
# Chunk 1584 (Length: 125):
# formation de la licence (système LMD).
# Avec,
# M = 100 si Mg ≥  15
# M = 20 (Mg – 10) si 10   <  Mg < 15
# M = 0 si Mg  ≤ 10
# --------------------------------------------------
#
# Chunk 1585 (Length: 182):
# Avec,
# M = 100 si Mg ≥  15
# M = 20 (Mg – 10) si 10   <  Mg < 15
# M = 0 si Mg  ≤ 10
# − R est un paramètre lié aux rangs du candidat durant sa formation de la licence (système LMD).
# --------------------------------------------------
#
# Chunk 1586 (Length: 163):
# − R est un paramètre lié aux rangs du candidat durant sa formation de la licence (système LMD).
# Il est calculé comme suit :
# R = (1/n) Σ Ri
# (où, n = 2).
#
# Avec,
# --------------------------------------------------
#
# Chunk 1587 (Length: 198):
# Il est calculé comme suit :
# R = (1/n) Σ Ri
# (où, n = 2).
#
# Avec,
# Ri = 100 – (700ri)/3 pour ri ≤ 0.3
# Ri = 0 pour ri > 0.3
# Où, ri est défini pour chaque année d’études de la manière suivante :
# --------------------------------------------------
#
# Chunk 1588 (Length: 184):
# Ri = 0 pour ri > 0.3
# Où, ri est défini pour chaque année d’études de la manière suivante :
#
# ri = (rang –1)/Effectif
#
# On ne tient compte que des deux premières années de formation.
# --------------------------------------------------
#
# Chunk 1589 (Length: 144):
# ri = (rang –1)/Effectif
#
# On ne tient compte que des deux premières années de formation.
# − B1 représente la bonification de l’âge du candidat.
# --------------------------------------------------
#
# Chunk 1590 (Length: 183):
# 2
# Avec,
# B1 = 5 si l’année de naissance ≥ l’année des concours -22
# B1 = 0  si l’année de naissance <l’année des concours -22
#
# − B2 représente la bonification du bac.
#
#
# Avec,
# --------------------------------------------------
#
# Chunk 1591 (Length: 196):
# − B2 représente la bonification du bac.
#
#
# Avec,
# B2 = 20 si moyenne du bac  ≥ 16
# B2 = 15 si 16 > moyenne du bac ≥ 14
# B2 = 10 si 14 > moyenne du bac ≥ 12
# B2 = 5 si 12 > moyenne du bac ≥ 11
# --------------------------------------------------
#
# Chunk 1592 (Length: 125):
# B2 = 10 si 14 > moyenne du bac ≥ 12
# B2 = 5 si 12 > moyenne du bac ≥ 11
# B2 = 0 si moyenne du bac < 11 ou session de contrôle
# --------------------------------------------------
#
# Chunk 1593 (Length: 176):
# B2 = 5 si 12 > moyenne du bac ≥ 11
# B2 = 0 si moyenne du bac < 11 ou session de contrôle
#
# - ML représente la moyenne arithmétique des moyennes des langues : français (MFr) et
# --------------------------------------------------
#
# Chunk 1594 (Length: 159):
# - ML représente la moyenne arithmétique des moyennes des langues : français (MFr) et
# anglais (MAng) ou autre (techniques de communication, droit de l’homme…)
# --------------------------------------------------
#
# Chunk 1595 (Length: 148):
# anglais (MAng) ou autre (techniques de communication, droit de l’homme…)
#                                          ML= Moyenne Langue =( MFr+MAng)/2
# --------------------------------------------------
#
# Chunk 1596 (Length: 131):
# ML= Moyenne Langue =( MFr+MAng)/2
#
#
#
# Les étudiants provenants des écoles préparatoires et qui ont une seule moyenne de deuxième
# --------------------------------------------------
#
# Chunk 1597 (Length: 191):
# Les étudiants provenants des écoles préparatoires et qui ont une seule moyenne de deuxième
# année licence peuvent la mettre comme moyenne de la 1ère année sur la platforme.
#
# b) Score E :
# --------------------------------------------------
#
# Chunk 1598 (Length: 105):
# b) Score E :
#
# Ce score sera calculé selon une formule spécifique pour chaque établissement de formation
# --------------------------------------------------
#
# Chunk 1599 (Length: 190):
# Ce score sera calculé selon une formule spécifique pour chaque établissement de formation
# d’ingénieurs. Il sera publié sur le site https://csingenieur.inscription.tn avant la date limite de
# --------------------------------------------------
#
# Chunk 1600 (Length: 34):
# dépôt des dossiers de candidature.
# --------------------------------------------------
#
# Chunk 1601 (Length: 143):
# 3
#
#
#
#
# Critères de Sélection des Candidats aux Concours Spécifiques d’accès
# aux Etablissements de Formation d’Ingénieurs
# (Deuxième année)
# --------------------------------------------------
#
# Chunk 1602 (Length: 140):
# aux Etablissements de Formation d’Ingénieurs
# (Deuxième année)
# La procédure de sélection des candidats aux Concours Spécifiques d’accès aux
# --------------------------------------------------
#
# Chunk 1603 (Length: 186):
# (Deuxième année)
# La procédure de sélection des candidats aux Concours Spécifiques d’accès aux
# Etablissements de Formation d ’Ingénieurs est basée sur un score qui est attribué à chaque
# --------------------------------------------------
#
# Chunk 1604 (Length: 183):
# Etablissements de Formation d ’Ingénieurs est basée sur un score qui est attribué à chaque
# candidat. Ce score tient compte de critères communs à tous les établissements concernés par
# --------------------------------------------------
#
# Chunk 1605 (Length: 182):
# candidat. Ce score tient compte de critères communs à tous les établissements concernés par
# ledit concours et il est calculé suivant la formule :
#
# Score  = C (M + B1 + B2)
# Où   :
# --------------------------------------------------
#
# Chunk 1606 (Length: 190):
# ledit concours et il est calculé suivant la formule :
#
# Score  = C (M + B1 + B2)
# Où   :
#
# • M est fonction de Mg qui est la moyenne générale des sessions principales de 1ère année licence
# --------------------------------------------------
#
# Chunk 1607 (Length: 195):
# • M est fonction de Mg qui est la moyenne générale des sessions principales de 1ère année licence
# (L1) , 2ème année licence (L2) et et 1ère année mastère (M1).
#
#
# Avec,
# M = 100 si Mg ≥  15
# --------------------------------------------------
#
# Chunk 1608 (Length: 152):
# (L1) , 2ème année licence (L2) et et 1ère année mastère (M1).
#
#
# Avec,
# M = 100 si Mg ≥  15
# M = 20 (Mg – 10) si 10   <  Mg < 15
# M = 0 si Mg  ≤ 10
# --------------------------------------------------
#
# Chunk 1609 (Length: 149):
# Avec,
# M = 100 si Mg ≥  15
# M = 20 (Mg – 10) si 10   <  Mg < 15
# M = 0 si Mg  ≤ 10
# • B1 représente la bonification de l’âge du candidat.
#
# Avec,
# --------------------------------------------------
#
# Chunk 1610 (Length: 141):
# M = 0 si Mg  ≤ 10
# • B1 représente la bonification de l’âge du candidat.
#
# Avec,
# B1 = 5 si L’année de naissance ≥ l’année des concours -24
# --------------------------------------------------
#
# Chunk 1611 (Length: 174):
# Avec,
# B1 = 5 si L’année de naissance ≥ l’année des concours -24
# B1 = 0  si L’année de naissance <l’année des concours -24
# • B2 représente la bonification du bac.
#
# Avec,
# --------------------------------------------------
#
# Chunk 1612 (Length: 191):
# • B2 représente la bonification du bac.
#
# Avec,
# B2 = 20 si moyenne du bac  ≥ 16
# B2 = 15 si 16 > moyenne du bac ≥ 14
# B2 = 10 si 14 > moyenne du bac ≥ 12
# B2 = 5 si 12 > moyenne du bac ≥ 11
# --------------------------------------------------
#
# Chunk 1613 (Length: 125):
# B2 = 10 si 14 > moyenne du bac ≥ 12
# B2 = 5 si 12 > moyenne du bac ≥ 11
# B2 = 0 si moyenne du bac < 11 ou session de contrôle
# --------------------------------------------------
#
# Chunk 1614 (Length: 105):
# 4
# • C  vaut :
# C = 1 pour les non-redoublants
# C = 0.8 pour les redoublants (un redoublement au maximum)
# --------------------------------------------------
#
# Chunk 1615 (Length: 121):
# Calcul Score E par filière
# ISI-UTM
#
# Filière Ingénierie du Développement Logiciel : IDL
# Type Mention Parcours Score E
# --------------------------------------------------
#
# Chunk 1616 (Length: 156):
# Type Mention Parcours Score E
# Licence Sciences Exactes et Technologies Science de l’Informatique UE Mathématique1 + UE Mathématique2 + (UE Algorithmique et
# --------------------------------------------------
#
# Chunk 1617 (Length: 121):
# programmation 1 + UE Algorithmique et programmation 2) / 2+
# UE CPOO + (UE Bases de données + UE compilation et tests) /2
# --------------------------------------------------
#
# Chunk 1618 (Length: 137):
# Licence Sciences Exactes et Technologies Ingénierie des Systèmes Informatiques UE Mathématique1 + UE Mathématique2 + (UE Algorithmique et
# --------------------------------------------------
#
# Chunk 1619 (Length: 122):
# programmation 1 + UE Algorithmique et programmation 2) / 2 +
#  UE Systèmes d'information S3 + UE Systèmes d'information S4
# --------------------------------------------------
#
# Chunk 1620 (Length: 189):
# Licence Sciences Exactes et Technologies Electronique, Electrotechnique et Automatique UE Mathématique1 + UE Mathématique2 + (UE Informatique 1 +
# UE Informatique 2) / 2 + UE Optionnelle S3
# --------------------------------------------------
#
# Chunk 1621 (Length: 88):
# UE Informatique 2) / 2 + UE Optionnelle S3
# + UE Programmation Orientée Objet et mobile
# --------------------------------------------------
#
# Chunk 1622 (Length: 130):
# Filière : Ingénierie et Développement des Infrastructures et des Services de Communications : IDISC
# Type Mention Parcours Score E
# --------------------------------------------------
#
# Chunk 1623 (Length: 161):
# Type Mention Parcours Score E
# Licence Sciences Exactes et Technologies Science de l’Informatique UE Mathématique 1 + UE Mathématique 2 + Fondements des réseaux+
# --------------------------------------------------
#
# Chunk 1624 (Length: 177):
# Services des Réseaux + Sécurité Informatique
# Licence Sciences Exactes et Technologies Ingénierie des Systèmes Informatiques UE Mathématique1 + UE Mathématique2 + (Initiation au
# --------------------------------------------------
#
# Chunk 1625 (Length: 87):
# traitement de signal + Transmission de données) /2 +Réseaux
# IP + Sécurité Informatique
# --------------------------------------------------
#
# Chunk 1626 (Length: 175):
# IP + Sécurité Informatique
#
# Licence Sciences Exactes et Technologies Electronique, Electrotechnique et Automatique UE Mathématique1 + UE Mathématique2 + traitement de signal
# --------------------------------------------------
#
# Chunk 1627 (Length: 77):
# Analogique + Transmission de données+ Programmation orientée
# objet et mobile
# --------------------------------------------------
#
# Chunk 1628 (Length: 106):
# Filière : Ingénierie des Systèmes Embarqués et Objets Connectés : ISEOC
#
#
# Type Mention Parcours Score E
# --------------------------------------------------
#
# Chunk 1629 (Length: 159):
# Type Mention Parcours Score E
# Licence Sciences Exactes et Technologies Science de l’Informatique UE Mathématique 1 + UE Mathématique 2 + (Systèmes logiques et
# --------------------------------------------------
#
# Chunk 1630 (Length: 144):
# architecture des ordinateurs + Programmation Python) /2 +
# Fondement de l’intelligence artificielle (Programmation IA) +
# Développement mobile
# --------------------------------------------------
#
# Chunk 1631 (Length: 164):
# Développement mobile
# Licence Sciences Exactes et Technologies Ingénierie des Systèmes Informatiques UE Mathématique1 + UE Mathématique2 + (Electricité-Electronique
# --------------------------------------------------
#
# Chunk 1632 (Length: 84):
# + Fonction Electronique)/2 + Architecture des ordinateurs+ Internet
# des objets, IoT
# --------------------------------------------------
#
# Chunk 1633 (Length: 162):
# des objets, IoT
# Licence Sciences Exactes et Technologies Electronique, Electrotechnique et Automatique UE Mathématique1 + UE Mathématique2 + (UE Electronique1  +
# --------------------------------------------------
#
# Chunk 1634 (Length: 188):
# UE Electronique2) /2 + (Architecture des microprocesseurs et
# microcontrôleurs + Capteurs et actionneurs) /2 + Conception des
# circuits numériques et synthèse VHDL+ Conception des systèmes
# --------------------------------------------------
#
# Chunk 1635 (Length: 76):
# circuits numériques et synthèse VHDL+ Conception des systèmes
# embarqués) /2
# --------------------------------------------------

# %%
embeddings = GoogleGenerativeAIEmbeddings(model="models/embedding-001",google_api_key=GOOGLE_API_KEY)


vector_index = Chroma.from_texts(
    texts=documents,                    # List of text chunks
    embedding=embeddings,               # Embedding model instance
    metadatas=metadata,                 # List of metadata for each document
)

# %%
vector_index = Chroma.from_texts(texts, embeddings).as_retriever(search_kwargs={"k":7})

# %%
qa_chain = RetrievalQA.from_chain_type(
    model,
    retriever=vector_index,
    return_source_documents=True,
    chain_type="refine",


)

# %%
def remove_repeated_phrases(text):
    # Split the text into sentences
    sentences = text.split(".")
    seen_sentences = set()
    filtered_sentences = []

    for sentence in sentences:
        if sentence.strip() not in seen_sentences:
            filtered_sentences.append(sentence.strip())
            seen_sentences.add(sentence.strip())

    # Join the filtered sentences back into a single response
    return ". ".join(filtered_sentences).strip() + "."

# %%
from langdetect import detect

# Détecter la langue de la question
question = "what is IDISC?"
langue_question = detect(question)

# Définir les paramètres de langue pour le modèle
if langue_question == 'fr':
    model_lang_param = 'fr'
elif langue_question == 'en':
    model_lang_param = 'en'
else:
    model_lang_param = 'fr'  # Défaut francais si langue inconnue

# Passer la question avec la langue au modèle, mais sans modifier la question affichée
result = qa_chain({
    "query": question,
    "language": model_lang_param  # Passer la langue comme paramètre interne
})

# Filtrer la réponse pour enlever les répétitions
filtered_answer = remove_repeated_phrases(result["result"])


print(filtered_answer)
question = "comment accèder au ingénierie?"
result = qa_chain({"query": question})

# Filtrer la réponse pour enlever les répétitions
filtered_answer = remove_repeated_phrases(result["result"])

print("Réponse affinée :")
print(filtered_answer)
# Out:
# Réponse affinée :
# **Refined Answer:**
#
# To access the engineering program at ISI, students can either:
#
# * Complete a bachelor's degree (Licence) with excellent results to be admitted to the first year of engineering (Première année ingénieur). * Complete the first year of a master's degree (M1) to be admitted to the second year of engineering (Deuxième année ingénieur). The context provided indicates that ISI offers three engineering specializations that last three years. Students can be admitted to the first year of engineering after completing a bachelor's degree with excellent results. Additionally, students who have completed the first year of a master's degree can be admitted to the second year of engineering. The specializations offered by ISI are:
#
# * Cybersecurity
# * Embedded systems
# * Internet of Things
#
# Please note that the admission requirements may vary depending on the specific specialization that you are interested in. It is recommended to contact ISI directly for more information..

# %%
question = "quel est la déclaration sociale et environnementale de l'ISI ?"
result = qa_chain({"query": question})
result["result"]
# Out:
# "**Refined Answer:**\n\nBased on the additional context, the ISI's social and environmental statement is that it recognizes the importance of voluntarily integrating social and environmental concerns into its activities, in line with its values of sustainability, ethics, and social responsibility. The ISI positions itself as a key player committed to this integration, particularly in the training of professionals through internships, final year projects (PFE), and the development of partnerships with the socio-economic world. This commitment is reflected in the ISI's educational programs and activities, and in its engagement with the wider community, as evidenced by the signing of around thirty partnerships in recent years.\n\nThe new context provides additional information about the ISI's specific efforts to promote eco-responsible behavior, such as adding greenery to common spaces and implementing a digitalization process to simplify administrative procedures. This suggests that the ISI is taking concrete steps to reduce its environmental impact and promote sustainability within its own operations.\n\nTherefore, the refined answer is:\n\n**The ISI's social and environmental statement is that it recognizes the importance of voluntarily integrating social and environmental concerns into its activities, in line with its values of sustainability, ethics, and social responsibility. The ISI positions itself as a key player committed to this integration, particularly in the training of professionals through internships, final year projects (PFE), and the development of partnerships with the socio-economic world. This commitment is reflected in the ISI's educational programs and activities, and in its engagement with the wider community, as evidenced by the signing of around thirty partnerships in recent years. The ISI is also taking concrete steps to promote eco-responsible behavior and reduce its environmental impact within its own operations, such as adding greenery to common spaces and implementing a digitalization process to simplify administrative procedures.**\n\nThe additional context has allowed us to provide a more detailed and specific answer to the question, highlighting the ISI's commitment to both social and environmental responsibility, and its efforts to implement these commitments in practical ways."

# %% [markdown]
# > Add blockquote

# %%
# Display the answer and the source documents (chunks used)
answer = result["result"]
source_chunks = result["source_documents"]

print("Answer:")
print(answer)
print("\nSource Chunks Used:")

# Print each source chunk and its content
for i, doc in enumerate(source_chunks):
    print(f"Chunk {i + 1}:\n{doc.page_content}\n{'-' * 50}")
# Out:
# Answer:
# **Refined Answer:**
#
# Based on the additional context, the ISI's social and environmental statement is that it recognizes the importance of voluntarily integrating social and environmental concerns into its activities, in line with its values of sustainability, ethics, and social responsibility. The ISI positions itself as a key player committed to this integration, particularly in the training of professionals through internships, final year projects (PFE), and the development of partnerships with the socio-economic world. This commitment is reflected in the ISI's educational programs and activities, and in its engagement with the wider community, as evidenced by the signing of around thirty partnerships in recent years.
#
# The new context provides additional information about the ISI's specific efforts to promote eco-responsible behavior, such as adding greenery to common spaces and implementing a digitalization process to simplify administrative procedures. This suggests that the ISI is taking concrete steps to reduce its environmental impact and promote sustainability within its own operations.
#
# Therefore, the refined answer is:
#
# **The ISI's social and environmental statement is that it recognizes the importance of voluntarily integrating social and environmental concerns into its activities, in line with its values of sustainability, ethics, and social responsibility. The ISI positions itself as a key player committed to this integration, particularly in the training of professionals through internships, final year projects (PFE), and the development of partnerships with the socio-economic world. This commitment is reflected in the ISI's educational programs and activities, and in its engagement with the wider community, as evidenced by the signing of around thirty partnerships in recent years. The ISI is also taking concrete steps to promote eco-responsible behavior and reduce its environmental impact within its own operations, such as adding greenery to common spaces and implementing a digitalization process to simplify administrative procedures.**
#
# The additional context has allowed us to provide a more detailed and specific answer to the question, highlighting the ISI's commitment to both social and environmental responsibility, and its efforts to implement these commitments in practical ways.
#
# Source Chunks Used:
# Chunk 1:
# Étant conscient de l’importance de l’intégration volontaire des préoccupations sociales et
# environnementales à ses activités, l’ISI se positionne comme un acteur essentiel engagé envers le
# --------------------------------------------------
# Chunk 2:
# Étant conscient de l’importance de l’intégration volontaire des préoccupations sociales et
# environnementales à ses activités, l’ISI se positionne comme un acteur essentiel engagé envers le
# --------------------------------------------------
# Chunk 3:
# valeurs telles que la durabilité, l'éthique et la responsabilité sociale. L'ISI s'engage à former des
# --------------------------------------------------
# Chunk 4:
# valeurs telles que la durabilité, l'éthique et la responsabilité sociale. L'ISI s'engage à former des
# --------------------------------------------------
# Chunk 5:
# et des stages PFE ainsi que le développement de partenariats avec le monde socio-économique.
#
#
#
#
#
#
#
#
#
# Ces dernières années, l ’ISI a signé une trentaine
# --------------------------------------------------
# Chunk 6:
# et des stages PFE ainsi que le développement de partenariats avec le monde socio-économique.
#
#
#
#
#
#
#
#
#
# Ces dernières années, l ’ISI a signé une trentaine
# --------------------------------------------------
# Chunk 7:
# comportements éco-responsables. Des efforts sont aussi déployés pour ajouter de la verdure dans
# les espaces communs. En outre, le processus de digitalisation mis en œuvre à l’ISI vise à simplifier
# --------------------------------------------------
